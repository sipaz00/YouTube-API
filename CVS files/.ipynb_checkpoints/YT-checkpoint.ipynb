# %%
import requests
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
import warnings
warnings.filterwarnings('ignore') # ignore warnings

# %% [markdown]
# Analysis of the YT Home Feed and Trending pages in 6 different countries

# %% [markdown]
# ## US ##

# %% [markdown]
# TRENDING

# %%
url = "https://yt-api.p.rapidapi.com/trending"

querystring = {"geo":"US"}

headers = {
	"x-rapidapi-key": "d31f7e5962msh64f6070990dee3dp1df11fjsnb7da1f2108ba",
	"x-rapidapi-host": "yt-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
US = response.json()
US = US['data']
df_US = pd.DataFrame(US)
df_US = df_US.drop(columns = [
    'videoId',
    'channelId',
    'channelHandle',
    'channelThumbnail',
    'publishedTimeText',
    'publishedAt',
    'thumbnail',
    'richThumbnail',
    'data'])

df_US['country'] = 'US'
df_US['date'] = pd.Timestamp.now().date() #fecha 
df_US.to_csv('trending 7 US.csv')

# %%
# df_US

# %% [markdown]
# HOME FEED

# %%
US_hf
# Out:
# {'error': 'Retry', 'code': '403'}

# %%
url = "https://yt-api.p.rapidapi.com/home"

querystring = {"geo":"US"}

headers = {
	"x-rapidapi-key": "d31f7e5962msh64f6070990dee3dp1df11fjsnb7da1f2108ba",
	"x-rapidapi-host": "yt-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
US_hf = response.json()
US_hf = US_hf['data']
df_US_hf = pd.DataFrame(US_hf)

df_US_hf = df_US_hf.drop(columns = [
    'videoId',
    'channelId',
    'channelTitle',
    'channelThumbnail',
    'publishedTimeText',
    'publishDate',
    'thumbnail',
    'richThumbnail',
    'channelId',
    'channelHandle',
    'publishedAt',
    'subtitle',
    'data'])
df_US_hf['country'] = 'US'
df_US_hf['date'] = pd.Timestamp.now().date() # add date column 
df_US_hf.to_csv('home feed 7 US.csv')

# %%
df_US_hf.columns
# Out:
# Index(['type', 'title', 'description', 'viewCount', 'lengthText', 'country',
#        'date'],
#       dtype='object')

# %% [markdown]
# ## ES ##

# %% [markdown]
# TRENDING

# %%
url = "https://yt-api.p.rapidapi.com/trending"

querystring = {"geo":"ES"}

headers = {
	"x-rapidapi-key": "d31f7e5962msh64f6070990dee3dp1df11fjsnb7da1f2108ba",
	"x-rapidapi-host": "yt-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
ES = response.json()
ES = ES['data']
df_ES = pd.DataFrame(ES)
df_ES = df_ES.drop(columns = [
    'videoId',
    'channelId',
    'channelHandle',
    'channelThumbnail',
    'publishedTimeText',
    'publishedAt',
    'thumbnail',
    'richThumbnail',
    'data'])

df_ES['country'] = 'ES'
df_ES['date'] = pd.Timestamp.now().date() #fecha 
df_ES.to_csv('trending 7 ES.csv')

# %%
df_ES.head(2)
# Out:
#     type                                              title channelTitle  \
# 0  video  🔴 PARTIDAZO DE YOUTUBERS 5 | ESPAÑA VS FRANCIA...     DjMaRiiO
# 1  video                 Shakira - Soltera (Official Video)      Shakira
#
#                                          description viewCount publishDate  \
# 0  ➜ENTRADAS PARTIDAZO DE YOUTUBES 5: https://ent...   3142355  2024-10-12
# 1  Music: \nApple Music:  https://Shakira.lnk.to/...   7261759  2024-10-12
#
#   lengthText country        date
# 0    5:08:35      ES  2024-10-13
# 1       4:09      ES  2024-10-13

# %% [markdown]
# HOME FEED

# %%
url = "https://yt-api.p.rapidapi.com/home"

querystring = {"geo":"ES"}

headers = {
	"x-rapidapi-key": "d31f7e5962msh64f6070990dee3dp1df11fjsnb7da1f2108ba",
	"x-rapidapi-host": "yt-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
ES_hf = response.json()
ES_hf = ES_hf['data']
df_ES_hf = pd.DataFrame(ES_hf)

df_ES_hf = df_ES_hf.drop(columns = [
    'videoId',
    'channelId',
    'channelTitle',
    'channelThumbnail',
    'publishedTimeText',
    'publishDate',
    'badges',
    'thumbnail',
    'richThumbnail',
    'channelId',
    'channelHandle',
    'publishedAt',
    'subtitle',
    'data'])
df_ES_hf['country'] = 'ES'
df_ES_hf['date'] = pd.Timestamp.now().date() # add date column 
df_ES_hf.to_csv('home feed 7 ES.csv')
df_ES_hf.head(3)
# Out:
#              type                                              title  \
# 0           video  Autumn Porch Vibes 🍂 Enchanting Jazz Playlist ...
# 1  shorts_listing                                             Shorts
# 2   video_listing                                           Trending
#
#                                          description viewCount lengthText  \
# 0  Autumn Porch Vibes 🍂 Enchanting Jazz Playlist ...      1769       LIVE
# 1                                                NaN       NaN        NaN
# 2                                                NaN       NaN        NaN
#
#   isLive country        date
# 0   True      ES  2024-10-16
# 1    NaN      ES  2024-10-16
# 2    NaN      ES  2024-10-16

# %% [markdown]
# ## FR

# %% [markdown]
# TRENDING

# %%
url = "https://yt-api.p.rapidapi.com/trending"

querystring = {"geo":"FR"}

headers = {
	"x-rapidapi-key": "d31f7e5962msh64f6070990dee3dp1df11fjsnb7da1f2108ba",
	"x-rapidapi-host": "yt-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
FR = response.json()
FR = FR['data']
df_FR = pd.DataFrame(FR)
df_FR = df_FR.drop(columns = [
    'videoId',
    'channelId',
    'channelHandle',
    'channelThumbnail',
    'publishedTimeText',
    'publishedAt',
    'thumbnail',
    'richThumbnail',
    'data'])
    
df_FR['country'] = 'FR'
df_FR['date'] = pd.Timestamp.now().date() # add date column 
df_FR.to_csv('trending 7 FR.csv')

# %%
df_FR.head(3)
# Out:
#              type                                              title  \
# 0           video  ÉNORME CACHE-CACHE dans une VILLE du DÉSERT ! ...
# 1           video                     JE RÉAGIS À "KAIZEN" D'INOXTAG
# 2  shorts_listing                                    Trending Shorts
#
#   channelTitle                                        description viewCount  \
# 0       Michou  Salut ! Aujourd’hui nouvelle vidéo ! Dans cett...   1402386
# 1    Mike Horn  🇫🇷 Cette année, Inoxtag a relevé un défi extra...    712181
# 2          NaN                                                NaN       NaN
#
#   publishDate lengthText country        date
# 0  2024-10-14      37:15      FR  2024-10-15
# 1  2024-10-14      20:28      FR  2024-10-15
# 2         NaN        NaN      FR  2024-10-15

# %% [markdown]
# HOME FEED

# %%
FR_hf
# Out:
# {'error': 'Retry', 'code': '403'}

# %%
url = "https://yt-api.p.rapidapi.com/home"

querystring = {"geo":"FR"}

headers = {
	"x-rapidapi-key": "d31f7e5962msh64f6070990dee3dp1df11fjsnb7da1f2108ba",
	"x-rapidapi-host": "yt-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
FR_hf = response.json()
FR_hf = FR_hf['data']
df_FR_hf = pd.DataFrame(FR_hf)

df_FR_hf = df_FR_hf.drop(columns = [
    'videoId',
    'channelId',
    'channelTitle',
    'channelThumbnail',
    'publishedTimeText',
    'publishDate',
    'badges',
    'thumbnail',
    'richThumbnail',
    'channelId',
    'channelHandle',
    'publishedAt',
    'subtitle',
    'data'])
df_FR_hf['country'] = 'FR'
df_FR_hf['date'] = pd.Timestamp.now().date() # add date column 
df_FR_hf.to_csv('home feed 7 FR.csv')
df_FR_hf.head(3)
# Out:
#              type                                              title  \
# 0           video  Smooth Fall Jazz Music at Cozy Coffee Shop Amb...
# 1  shorts_listing                                             Shorts
# 2   video_listing                                           Trending
#
#                                          description viewCount lengthText  \
# 0  Smooth Fall Jazz Music at Cozy Coffee Shop Amb...    125994   11:54:57
# 1                                                NaN       NaN        NaN
# 2                                                NaN       NaN        NaN
#
#   isLive country        date
# 0    NaN      FR  2024-10-16
# 1    NaN      FR  2024-10-16
# 2    NaN      FR  2024-10-16

# %% [markdown]
# ## Italy

# %% [markdown]
# TRENDING

# %%
url = "https://yt-api.p.rapidapi.com/trending"

querystring = {"geo":"IT"}

headers = {
	"x-rapidapi-key": "d31f7e5962msh64f6070990dee3dp1df11fjsnb7da1f2108ba",
	"x-rapidapi-host": "yt-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
IT = response.json()
IT = IT['data']
df_IT = pd.DataFrame(IT)
df_IT = df_IT.drop(columns = [
    'videoId',
    'channelId',
    'channelHandle',
    'channelThumbnail',
    'publishedTimeText',
    'publishedAt',
    'thumbnail',
    'richThumbnail',
    'data'])
    
df_IT['country'] = 'IT'
df_IT['date'] = pd.Timestamp.now().date() # add date column 
df_IT.to_csv('trending 7 IT.csv')

# %%
df_IT.head(3)
# Out:
#     type                                              title  channelTitle  \
# 0  video                                             CNTNRS  Night Skinny
# 1  video                   85 dollars for pasta in a GLASS?     Lionfield
# 2  video  Uragano Milton verso la Florida: come affronta...        Geopop
#
#                                          description viewCount publishDate  \
# 0  ► Ascolta “CNTNRS”\nhttps://island.lnk.to/CNTN...     89840  2024-10-10
# 1                                                      1703409  2024-10-07
# 2  L'uragano Milton sta arrivando in Florida, con...    477026  2024-10-10
#
#   lengthText country        date
# 0       5:28      IT  2024-10-11
# 1       0:24      IT  2024-10-11
# 2       8:36      IT  2024-10-11

# %% [markdown]
# HOME FEED

# %%
IT_hf
# Out:
# {'filters': [{'filter': 'All'},
#   {'filter': 'Music',
#    'continuation': '...%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Gaming',
#    'continuation': '...%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Action Thrillers',
#    'continuation': '....CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Live',
#    'continuation': '...%3D%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Playlists',
#    'continuation': '...%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'DRAGON BALL: Sparking! ZERO',
#    'continuation': '...%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Podcasts',
#    'continuation': '...%3D%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Free music',
#    'continuation': '...%3D%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Quarterbacks',
#    'continuation': '...%3D%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Unboxing',
#    'continuation': '...%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Romantic comedies',
#    'continuation': '....CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Baseball',
#    'continuation': '...%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Dramedy',
#    'continuation': '...%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Baking',
#    'continuation': '....CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Steering wheels',
#    'continuation': '...%3D%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Reading',
#    'continuation': '...%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Rapping',
#    'continuation': '....CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Visual arts',
#    'continuation': '...%3D%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Role-Playing Games',
#    'continuation': '...%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'},
#   {'filter': 'Recently uploaded',
#    'continuation': '...%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D'}],
#  'continuation': '...%3D.CgtaN004UURWWTdxcyiA8KS4BjIKCgJERRIEEgAgZw%3D%3D',
#  'data': [{'type': 'video',
#    'videoId': 'IxcHdGkYgfM',
#    'title': 'Warm Morning Jazz Music at Fall Coffee Shop Ambience 🍂 Relaxing Jazz Instrumental Music for Studying',
#    'channelTitle': 'Relax Jazz Cafe',
#    'channelId': 'UCZR3-lM6Z-n5_UGHlwx_Rpw',
#    'channelHandle': '@RelaxJazzCafe1990',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/JmVjPt3lG3Vl-XacT3r3sn8cEoKrblDMwNhPUPJ7kRRjIzliH6SvNsS9pj2k5Q4jd8QVYK-kMQ=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': "Warm Morning Jazz Music at Fall Coffee Shop Ambience 🍂 Relaxing Jazz Instrumental Music for Studying\n\n👉️🎼 Let's experience the great music on Spotify of Relax Jazz Cafe. Register...",
#    'viewCount': '193622',
#    'publishedTimeText': '2 weeks ago',
#    'publishDate': '2024-10-02',
#    'publishedAt': '2024-10-02T00:00:00Z',
#    'lengthText': '11:54:57',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/IxcHdGkYgfM/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCWk1rfBCYMbLrOT03aWEO-p8WaoA',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/IxcHdGkYgfM/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBQCdqfSMkfYdP2OmkttsRoJVtB_Q',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/IxcHdGkYgfM/mqdefault_6s.webp?du=3000&sqp=CJDavbgG&rs=AOn4CLBVS-8vWygzx0X2P13d5Sw2v4NADQ',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'shorts_listing',
#    'title': 'Shorts',
#    'subtitle': None,
#    'data': [{'type': 'shorts',
#      'videoId': 'hkR3dPvwbf0',
#      'title': 'Day 2 Of ONLY Eating Food From a Korean Convenience Store!',
#      'viewCountText': '25M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/hkR3dPvwbf0/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSbQBL8c-SF4AjRZ8qCLYsqhkAcC',
#      'sequenceParams': 'Cgtoa1IzZFB2d2JmMCoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 'TwgQDduutGo',
#      'title': 'cute baby boy is playing with huge male lion',
#      'viewCountText': '4.9M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/TwgQDduutGo/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSYyki5bcnv4BuFQknkoT-sNkAcC',
#      'sequenceParams': 'CgtUd2dRRGR1dXRHbyoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 'O1v_gXnd27E',
#      'title': 'day vs night 💀..... #shorts #couple #funny',
#      'viewCountText': '17M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/O1v_gXnd27E/frame0.jpg',
#        'width': 720,
#        'height': 1280}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSasPv8MAx1RC03bA56xG1dvkAcC',
#      'sequenceParams': 'CgtPMXZfZ1huZDI3RSoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 's_Dzi25X5AM',
#      'title': 'Lamine Yamal Skills 💫',
#      'viewCountText': '41M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/s_Dzi25X5AM/frame0.jpg',
#        'width': 1080,
#        'height': 1440}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSadDl3oL3YQrSTDSM9hBi-8kAcC',
#      'sequenceParams': 'CgtzX0R6aTI1WDVBTSoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 'Qadjf-r1t6U',
#      'title': 'Filet-O-Gator @ChefRush @GugaFoods',
#      'viewCountText': '159M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/Qadjf-r1t6U/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSYyANMsD_mtI501Op0BzeafkAcC',
#      'sequenceParams': 'CgtRYWRqZi1yMXQ2VSoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 'mJF6k0Esa0E',
#      'title': 'WHAT KIDS SEE  vs WHAT PARENTS SEE',
#      'viewCountText': '81M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/mJF6k0Esa0E/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSZsouTpODfZXW2bYoDpOxLBkAcC',
#      'sequenceParams': 'CgttSkY2azBFc2EwRSoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 'yM7e6o976PI',
#      'title': 'Respect Cristiano Ronaldo ❤️ #shorts #ronaldo #messi #shortsvideo',
#      'viewCountText': '26M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/yM7e6o976PI/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSawNtUXMs-z07sNksBI51rYkAcC',
#      'sequenceParams': 'Cgt5TTdlNm85NzZQSSoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 'rijp-U9JArA',
#      'title': 'Nature is to Tymlez, Aaliyah is to Cesh 😂🤍',
#      'viewCountText': '4.1M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/rijp-U9JArA/frame0.jpg',
#        'width': 720,
#        'height': 1280}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSbb8fx34yQQ4XGOdzK4iutZkAcC',
#      'sequenceParams': 'CgtyaWpwLVU5SkFyQSoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 'GNdgzAczOlg',
#      'title': 'Minha vira-lata caramelo virou bolo 😅 #pets #cake',
#      'viewCountText': '35M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/GNdgzAczOlg/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSZnAAU_4Huj1w-r7npZkW7lkAcC',
#      'sequenceParams': 'CgtHTmRnekFjek9sZyoCGAVQGWgA'}]},
#   {'type': 'video_listing',
#    'title': 'Trending',
#    'subtitle': None,
#    'data': [{'type': 'video',
#      'videoId': 'aZ7ijVhq0zw',
#      'title': 'Shiva - Pluh (Official video)',
#      'channelTitle': 'SHIVA',
#      'channelId': 'UC4G1i2ZO5z6p5vBGcHM6PaQ',
#      'channelThumbnail': [{'url': 'https://yt3.ggpht.com/50apgaLXmJUAKo3rtZdhqlWzrwbYcyT19AsZvP01ZCWeWx2KLsbkd3xMaP_7RIqXYK9eftD_fR0=s88-c-k-c0x00ffffff-no-rj',
#        'width': 68,
#        'height': 68}],
#      'description': 'Ascolta ora su Spotify “Pluh” : https://shiva.bio/pluhspotify\n\nAscolta ora Milano Angels: https://shiva.bio/milanoangels\n\nISCRIVITI AL CANALE: https://www.youtube.com/channel/UC4G1i2ZO5z6p5vBGc...',
#      'viewCount': '127289',
#      'publishedTimeText': '16 hours ago',
#      'publishDate': '2024-10-15',
#      'publishedAt': '2024-10-15T00:00:00Z',
#      'lengthText': '2:59',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/aZ7ijVhq0zw/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAs-xE8PK7zyRWG-Bws1D7YLz68fQ',
#        'width': 360,
#        'height': 202},
#       {'url': 'https://i.ytimg.com/vi/aZ7ijVhq0zw/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDLlGrTDqUKhzpcUV3VXWGjv1E6OA',
#        'width': 720,
#        'height': 404}],
#      'richThumbnail': None},
#     {'type': 'video',
#      'videoId': 'D4hAbwT_w5g',
#      'title': "L'intervista a Pep Guardiola e Roberto Baggio | Che tempo che fa",
#      'channelTitle': 'NOVE',
#      'channelId': 'UCUbQUzFjyDtRw-311tyvyzw',
#      'channelHandle': '@NOVE9',
#      'channelThumbnail': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_ljAPXBqBz5tcS1_mHly2e4AeZI7gHUWOqr__am7XtEOzU=s68-c-k-c0x00ffffff-no-rj',
#        'width': 68,
#        'height': 68}],
#      'description': 'Che tempo che fa ti aspetta ogni domenica dalle 19.30 sul NOVE! 🐟🐟\nNon perderti le interviste di Fabio Fazio. \n\nGUARDA tutti i migliori contenuti di Che tempo che fa qui: https://www.youtube....',
#      'viewCount': '224159',
#      'publishedTimeText': '2 days ago',
#      'publishDate': '2024-10-14',
#      'publishedAt': '2024-10-14T00:00:00Z',
#      'lengthText': '18:29',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/D4hAbwT_w5g/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB2WYWYUgXUwVb5ybpTXWWfqOfusQ',
#        'width': 360,
#        'height': 202},
#       {'url': 'https://i.ytimg.com/vi/D4hAbwT_w5g/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAJdTAzijRWga7Jcrn-9pKI6WnvAQ',
#        'width': 720,
#        'height': 404}],
#      'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/D4hAbwT_w5g/mqdefault_6s.webp?du=3000&sqp=CMCwvbgG&rs=AOn4CLBaLreGvBI8ELxnRdylK_WikdtRIg',
#        'width': 320,
#        'height': 180}]},
#     {'type': 'video',
#      'videoId': 'WG6ZMn6QmTs',
#      'title': 'Highlights: Italia-Israele 4-1 | Nations League 2024/25',
#      'channelTitle': 'FIGC Azzurri e Azzurre',
#      'channelId': 'UCUnVodBnteAdGONNcUpS_kw',
#      'channelHandle': '@nazionaledicalcio',
#      'channelThumbnail': [{'url': 'https://yt3.ggpht.com/3VKRMEC6rcY8cbMh9mCVbrVIq8PkW9BE_a_KT8tUAF-QZKLWGmDzJF0Rb3kSiCByjhxSLGO6fw=s68-c-k-c0x00ffffff-no-rj',
#        'width': 68,
#        'height': 68}],
#      'description': 'A Udine gli Azzurri di Spalletti trovano il vantaggio in chiusura di primo tempo grazie al rigore trasformato da Retegui. A inizio ripresa Di Lorenzo raddoppia, ma gli ospiti accorciano le...',
#      'viewCount': '92435',
#      'publishedTimeText': '16 hours ago',
#      'publishDate': '2024-10-15',
#      'publishedAt': '2024-10-15T00:00:00Z',
#      'lengthText': '2:03',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/WG6ZMn6QmTs/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLApub0kuXhzQ2Xcx4_VZMAKLg-jZQ',
#        'width': 360,
#        'height': 202},
#       {'url': 'https://i.ytimg.com/vi/WG6ZMn6QmTs/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDs7CHpXNY_pdc5hGNk122fZpXS9w',
#        'width': 720,
#        'height': 404}],
#      'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/WG6ZMn6QmTs/mqdefault_6s.webp?du=3000&sqp=CPujvbgG&rs=AOn4CLB-NWc80figXsoFu-1cprCe_JGvqw',
#        'width': 320,
#        'height': 180}]},
#     {'type': 'video',
#      'videoId': 'fQfvkym38MM',
#      'title': 'Jannik Sinner vs Novak Djokovic For The Title 🏆  | Shanghai 2024 Final Highlights',
#      'channelTitle': 'Tennis TV',
#      'channelId': 'UCbcxFkd6B9xUU54InHv4Tig',
#      'channelHandle': '@tennistv',
#      'channelThumbnail': [{'url': 'https://yt3.ggpht.com/e8R56awJzeWRjYnFPV67P4eR03w9uxdXH0YBLECuiShj5Fr_rNJCJsiUbSG-u2cPiw_aSYiVeA=s68-c-k-c0x00ffffff-no-rj',
#        'width': 68,
#        'height': 68}],
#      'description': 'SUBSCRIBE to our channel for the best ATP tennis videos and tennis highlights: https://www.youtube.com/tennistv?sub_confirmation=1\n\nWatch official ATP tennis streams from every tournament:...',
#      'viewCount': '1524535',
#      'publishedTimeText': '2 days ago',
#      'publishDate': '2024-10-14',
#      'publishedAt': '2024-10-14T00:00:00Z',
#      'lengthText': '8:14',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/fQfvkym38MM/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDg7c0XHlP3-uLvuPtoKruWvDHqfA',
#        'width': 360,
#        'height': 202},
#       {'url': 'https://i.ytimg.com/vi/fQfvkym38MM/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBgZbO2vuL8zdPP-zovAXZ6Nv_ZXQ',
#        'width': 720,
#        'height': 404}],
#      'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/fQfvkym38MM/mqdefault_6s.webp?du=3000&sqp=CN7RvbgG&rs=AOn4CLA5gmiJviMIddYi2rkAEKzKAnE3Ow',
#        'width': 320,
#        'height': 180}]},
#     {'type': 'video',
#      'videoId': '_6cpIPMkINo',
#      'title': 'COSA VUOL DIRE ABITARE IN CAMPER 😳',
#      'channelTitle': 'Fil',
#      'channelId': 'UCz5u9rHDlIJUS4YjyioWgVw',
#      'channelHandle': '@Fil',
#      'channelThumbnail': [{'url': 'https://yt3.ggpht.com/l0hW6BBTMm10NR1qo1CBLesTnVOOa51N94sjJJNKzB7YpHseNqvoDTKMPw7bkJEsEVjvgfe4zQ=s68-c-k-c0x00ffffff-no-rj',
#        'width': 68,
#        'height': 68}],
#      'description': 'Ci vediamo su Instagram 💖 💖 https://instagram.com/filippocandotti\n\nIl mio secondo canale: https://www.youtube.com/c/FilippoCandotti\n\nciau :3',
#      'viewCount': '61981',
#      'publishedTimeText': '16 hours ago',
#      'publishDate': '2024-10-15',
#      'publishedAt': '2024-10-15T00:00:00Z',
#      'lengthText': '11:27',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/_6cpIPMkINo/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB2GeKid1stLfI30FRdiB1m63ls_A',
#        'width': 360,
#        'height': 202},
#       {'url': 'https://i.ytimg.com/vi/_6cpIPMkINo/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCfSK0yoHKv5TeTkpRrCsp8bpp5zQ',
#        'width': 720,
#        'height': 404}],
#      'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/_6cpIPMkINo/mqdefault_6s.webp?du=3000&sqp=CMTDvbgG&rs=AOn4CLA-9eZbXMFiu5NElduguc_R6aXcBg',
#        'width': 320,
#        'height': 180}]},
#     {'type': 'video',
#      'videoId': 'nSnBd-kDogA',
#      'title': 'Teraleak: Gen 10 e Pokémon ZA - Analisi Leak Live w/ Cydonia',
#      'channelTitle': 'Cydonia & Chiara',
#      'channelId': 'UC2kjrfX4rwTgkh5FafHK-uw',
#      'channelHandle': '@CydoniaChiara',
#      'channelThumbnail': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_lp7kwmHoEG5cfxduEGRqQEaoVwpSVEM1nQ2Pi5m99Vcg=s68-c-k-c0x00ffffff-no-rj',
#        'width': 68,
#        'height': 68}],
#      'description': '00:00 - Countdown\n10:42 - Introduzione sulla questione Teraleak\n16:40 - Aspettative sulla live\n19:42 - Questione morale\n23:57 - Prima premessa: perché Live e non Video sui Leak di 10 gen?...',
#      'viewCount': '23746',
#      'publishedTimeText': '13 hours ago',
#      'publishDate': '2024-10-15',
#      'publishedAt': '2024-10-15T00:00:00Z',
#      'lengthText': '3:22:45',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/nSnBd-kDogA/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC2cB7basNftaoHVGRxd9MQ-YzhKQ',
#        'width': 360,
#        'height': 202},
#       {'url': 'https://i.ytimg.com/vi/nSnBd-kDogA/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC1U0RGd0GlamxL3Uo4Naktif9ZLA',
#        'width': 720,
#        'height': 404}],
#      'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/nSnBd-kDogA/mqdefault_6s.webp?du=3000&sqp=CIDTvbgG&rs=AOn4CLCiSSnMezT_UbpyfIEUjE7aZjG-2A',
#        'width': 320,
#        'height': 180}]},
#     {'type': 'video',
#      'videoId': 'sbsS6UtsoQE',
#      'title': 'PENSIONI ➡ IMPORTI ESATTI TREDICESIMA 2024 AUMENTATI e in ANTEPRIMA 📈 verifica CALCOLI NETTI INPS',
#      'channelTitle': 'Mr LUL lepaghediale',
#      'channelId': 'UCqqTzN2V58Amy3Pfg1u7SMQ',
#      'channelHandle': '@MrLULlepaghediale',
#      'channelThumbnail': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_nNRZ4TgckKNwhN2ov9FJVqvQE7FUGFfa8hwG5wceCgosI=s68-c-k-c0x00ffffff-no-rj',
#        'width': 68,
#        'height': 68}],
#      'description': 'TREDICESIMA PENSIONI 2024 COME VEDERE ADESSO IN ANTEPRIMA GLI IMPORTI ESATTI LORDI E NETTI SUL SITO INPS e IL BONUS 155€ \n\nTREDICESIMA PENSIONI 2024, VI MOSTRO COME VEDERE L’IMPORTO UFFICIALE...',
#      'viewCount': '72451',
#      'publishedTimeText': '22 hours ago',
#      'publishDate': '2024-10-15',
#      'publishedAt': '2024-10-15T00:00:00Z',
#      'lengthText': '3:24',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/sbsS6UtsoQE/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAwGeGwwwjsdvFwqL95oeBLE_Wzvg',
#        'width': 360,
#        'height': 202},
#       {'url': 'https://i.ytimg.com/vi/sbsS6UtsoQE/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDbwF20ouimfViDlDDPuW__8EzUQA',
#        'width': 720,
#        'height': 404}],
#      'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/sbsS6UtsoQE/mqdefault_6s.webp?du=3000&sqp=CK3lvbgG&rs=AOn4CLA2qFIoNSvf05wkhSAxttzKjtr6jw',
#        'width': 320,
#        'height': 180}]},
#     {'type': 'video',
#      'videoId': 'uzwj-RCvPsg',
#      'title': 'La zanzara del 15/10/2024',
#      'channelTitle': 'Radio 24',
#      'channelId': 'UCuiPzxEpLJLTRu2HXzY3gfA',
#      'channelHandle': '@Radio24video',
#      'channelThumbnail': [{'url': 'https://yt3.ggpht.com/46MjT8-gJLsJnHvX303aLvJ-9-peEy9bovWHlUKOdys2rhqw_jf2pminiBPP5gFINkxD84RU=s68-c-k-c0x00ffffff-no-rj',
#        'width': 68,
#        'height': 68}],
#      'description': '',
#      'viewCount': '28603',
#      'publishedTimeText': '13 hours ago',
#      'publishDate': '2024-10-15',
#      'publishedAt': '2024-10-15T00:00:00Z',
#      'lengthText': '2:14:02',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/uzwj-RCvPsg/hq720.jpg?sqp=-oaymwE2COgCEMoBSFXyq4qpAygIARUAAIhCGAFwAcABBvABAfgB_gmAAtAFigIMCAAQARggIGUoKzAP&rs=AOn4CLCA7l823tMMixTE9Jvsqc9c8DRSbA',
#        'width': 360,
#        'height': 202},
#       {'url': 'https://i.ytimg.com/vi/uzwj-RCvPsg/hq720.jpg?sqp=-oaymwE2CNAFEJQDSFXyq4qpAygIARUAAIhCGAFwAcABBvABAfgB_gmAAtAFigIMCAAQARggIGUoKzAP&rs=AOn4CLBFkewSWe1A2az7s6kE1xkLRvnaVw',
#        'width': 720,
#        'height': 404}],
#      'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/uzwj-RCvPsg/mqdefault_6s.webp?du=3000&sqp=CIDivbgG&rs=AOn4CLARKuTc0ney8thkeP9kPSboK0pakA',
#        'width': 320,
#        'height': 180}]},
#     {'type': 'video',
#      'videoId': '32W3FRVBfRA',
#      'title': 'Me contro Te - LA CASA DEI MOSTRI (Videoclip Ufficiale)',
#      'channelTitle': 'Me contro Te Music',
#      'channelId': 'UCwjrf475hoHRJZc5SMnZzng',
#      'channelHandle': '@MecontroTeMusic',
#      'channelThumbnail': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_nqggfZ9UhfDNYhXanCjxT6KIgl69Jk9rx6dKdonRPrTnM=s68-c-k-c0x00ffffff-no-rj',
#        'width': 68,
#        'height': 68}],
#      'description': 'La Casa dei Mostri è la canzone ufficiale di Halloween per ballare e cantare con Streghe, Scheletri, Mummie e Zombie!\n\nTESTO:\nC’è un fantasma che si scatena\nCon la sua catena\nPer una notte...',
#      'viewCount': '216967',
#      'publishedTimeText': '3 days ago',
#      'publishDate': '2024-10-13',
#      'publishedAt': '2024-10-13T00:00:00Z',
#      'lengthText': '2:13',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/32W3FRVBfRA/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCny2T0BdhGUnvEW2OPXeiP_ScVIw',
#        'width': 360,
#        'height': 202},
#       {'url': 'https://i.ytimg.com/vi/32W3FRVBfRA/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLATGvtfeU0sH8BGZevUtihADm1kTQ',
#        'width': 720,
#        'height': 404}],
#      'richThumbnail': None},
#     {'type': 'video',
#      'videoId': 'UMJZbYmzMm8',
#      'title': 'La VERA ITALIA di Spalletti, Dimarco ricorda Beckham. Balotelli torna in A? | Fontana di Trevi',
#      'channelTitle': 'CRONACHE DI SPOGLIATOIO',
#      'channelId': 'UCfmCGVXfpAMSi4PP8kqWlbA',
#      'channelHandle': '@CRONACHEDISPOGLIATOIO',
#      'channelThumbnail': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_nAultEsXdsp34SFwUN3PpG13Ak1iWVXfppCVpXq2gvIQ=s68-c-k-c0x00ffffff-no-rj',
#        'width': 68,
#        'height': 68}],
#      'description': "Fernando Siani, Giuseppe Pastore, Samuele Ragusa e Riccardo Trevisani vi aspettano per la quinta puntata della nuova stagione di Fontana di Trevi, l'approfondimento del lunedì sera di Cronache...",
#      'viewCount': '107222',
#      'publishedTimeText': '1 day ago',
#      'publishDate': '2024-10-15',
#      'publishedAt': '2024-10-15T00:00:00Z',
#      'lengthText': '2:34:31',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/UMJZbYmzMm8/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCuiF_LLZGDGMl26v54pEbm8xDlcA',
#        'width': 360,
#        'height': 202},
#       {'url': 'https://i.ytimg.com/vi/UMJZbYmzMm8/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDIVmukxAD2pPDZ_X0nak13skia2Q',
#        'width': 720,
#        'height': 404}],
#      'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/UMJZbYmzMm8/mqdefault_6s.webp?du=3000&sqp=CO_GvbgG&rs=AOn4CLDWrTCcdmdo47etHqww6XHhJxpCpQ',
#        'width': 320,
#        'height': 180}]},
#     {'type': 'video',
#      'videoId': 'XcXaUA7EPrc',
#      'title': 'Le-one, Christian Liguori, Babywyne - NUN È OVER',
#      'channelTitle': 'le one',
#      'channelId': 'UCMfXnR0bJZx7zp0m9DJWiuQ',
#      'channelThumbnail': [{'url': 'https://yt3.ggpht.com/GqamXOsOp5_CQac7PR5jzTgSCcoCwKikpUL8KyBc5s7yqbpln3FZe3kxRYiWu5f0zj4mz8PN=s88-c-k-c0x00ffffff-no-rj',
#        'width': 68,
#        'height': 68}],
#      'description': 'Music video by Le-one, Christian Liguori, Babywyne performing NUN È OVER.An Epic release (C) 2024 Sony Music Entertainment Italy S.p.A',
#      'viewCount': '174962',
#      'publishedTimeText': '4 days ago',
#      'publishDate': '2024-10-12',
#      'publishedAt': '2024-10-12T00:00:00Z',
#      'lengthText': '1:58',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/XcXaUA7EPrc/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCk4Mqw0nLkOT2KbHKguMKsrWpjBg',
#        'width': 360,
#        'height': 202},
#       {'url': 'https://i.ytimg.com/vi/XcXaUA7EPrc/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA82k-_S1sODTzJyA3TWsy0cJttDg',
#        'width': 720,
#        'height': 404}],
#      'richThumbnail': None},
#     {'type': 'video',
#      'videoId': 'hopCI_-Bnqc',
#      'title': 'STARSHIP SpaceX : Quinto lancio  [LIVE]',
#      'channelTitle': 'link4universe',
#      'channelId': 'UCHRTziAevLPgAE9Y5VhSs5g',
#      'channelHandle': '@link4universe',
#      'channelThumbnail': [{'url': 'https://yt3.ggpht.com/mqZeEeyvkc4p0It5_k4L1dtFnYClMK9fdX8mzUN5ignl1OspaP_s1OwKczvT036V_1QG727eNw=s68-c-k-c0x00ffffff-no-rj',
#        'width': 68,
#        'height': 68}],
#      'description': 'Siamo alla vigilia del quinto lancio di prova della Starship, di SpaceX! Questa volta, oltre a tutte le cose incredibili del quarto volo, sarà tentato anche il recupero del primo stadio! ...',
#      'viewCount': '133953',
#      'publishedTimeText': '2 days ago',
#      'publishDate': '2024-10-14',
#      'publishedAt': '2024-10-14T00:00:00Z',
#      'lengthText': '5:47:22',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/hopCI_-Bnqc/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAta9ZohdGdXjTSqjxJUyIpFis_dA',
#        'width': 360,
#        'height': 202},
#       {'url': 'https://i.ytimg.com/vi/hopCI_-Bnqc/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCgEob3qlktFGYmPG_Et42ECm3C1A',
#        'width': 720,
#        'height': 404}],
#      'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/hopCI_-Bnqc/mqdefault_6s.webp?du=3000&sqp=CLHjvbgG&rs=AOn4CLA3tFp5e2qgtM7ll0Z3Po0gkzr_Qw',
#        'width': 320,
#        'height': 180}]}]},
#   {'type': 'shorts_listing',
#    'title': 'Shorts',
#    'subtitle': None,
#    'data': [{'type': 'shorts',
#      'videoId': 'xA2AIDBq8Fg',
#      'title': 'Twinkle toes were the FLYEST 😤 #animations #artshorts #humor #sneakers #drawing #ocs #memes',
#      'viewCountText': '3.6M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/xA2AIDBq8Fg/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSYnsROB7t0B5pMFZKku-mzmkAcC',
#      'sequenceParams': 'Cgt4QTJBSURCcThGZyoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': '2SsT5_zpVqc',
#      'title': 'Tiffany Stratton gets heckled by Fan #wwe #wwesupershow #wrestling #wweraw #wwenxt #beckylynch',
#      'viewCountText': '61M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/2SsT5_zpVqc/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSZ6wQMXSgHnvJ3UOefxH7RxkAcC',
#      'sequenceParams': 'CgsyU3NUNV96cFZxYyoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 'jWBnGwuwPBw',
#      'title': 'Would you WALK here? BEVERLY HILLS 🌴 California 🇺🇸',
#      'viewCountText': '8M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/jWBnGwuwPBw/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSbFjDTmBZqiTPqngwJmxHAskAcC',
#      'sequenceParams': 'CgtqV0JuR3d1d1BCdyoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 'Px_G1MXtXD8',
#      'title': 'Camel 🐪 style #shorts',
#      'viewCountText': '34M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/Px_G1MXtXD8/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSaAnVqHCLAPuaDcm1vlLaqwkAcC',
#      'sequenceParams': 'CgtQeF9HMU1YdFhEOCoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 'V4sULbKGLOw',
#      'title': 'Simple DIY big snake trap using Knife#creativesnaketrap',
#      'viewCountText': '81M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/V4sULbKGLOw/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSbbBiTwwQ0-xJktpbri-E8WkAcC',
#      'sequenceParams': 'CgtWNHNVTGJLR0xPdyoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': '1L14seR2yj8',
#      'title': 'The best Aura Moment ☠️ #shorts #trollface #aura',
#      'viewCountText': '8.9M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/1L14seR2yj8/frame0.jpg',
#        'width': 1080,
#        'height': 1906}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSZxkl1Ipr3-pkmkTQLh4NbRkAcC',
#      'sequenceParams': 'CgsxTDE0c2VSMnlqOCoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 'qDbnX0Kn-mI',
#      'title': 'Twins fall in love',
#      'viewCountText': '1.8M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/qDbnX0Kn-mI/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSY_9P1-5IO35fNAkZe5rl2PkAcC',
#      'sequenceParams': 'CgtxRGJuWDBLbi1tSSoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 's0QQLLROodo',
#      'title': 'حقش بود؟🫣بفرست براش که بدونه 😁',
#      'viewCountText': '4.1M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/s0QQLLROodo/frame0.jpg',
#        'width': 1080,
#        'height': 1920}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSbzoo-Ph6afO7spNJaQ8GyQkAcC',
#      'sequenceParams': 'CgtzMFFRTExST29kbyoCGAVQGWgA'},
#     {'type': 'shorts',
#      'videoId': 'm891u-owKro',
#      'title': 'Kids in this generation #shorts',
#      'viewCountText': '3.7M views',
#      'thumbnail': [{'url': 'https://i.ytimg.com/vi/m891u-owKro/frame0.jpg',
#        'width': 720,
#        'height': 1280}],
#      'isOriginalAspectRatio': True,
#      'params': 'CAUwAg%3D%3D',
#      'playerParams': '8AEBoAMByAMkuAQFogYVAa6PwSYBItfNd3T94Bahzjv9UXJrkAcC',
#      'sequenceParams': 'CgttODkxdS1vd0tybyoCGAVQGWgA'}]},
#   {'type': 'video',
#    'videoId': 'ofhnqJWFuNI',
#    'title': 'Tronditet Tirana! Gardisti qëllon veten me armë, ja çfarë dyshojnë familjarët…',
#    'channelTitle': 'Euronews Albania',
#    'channelId': 'UChR-A__NS_C5kHDWj3PeAhw',
#    'channelHandle': '@EuronewsAlbania',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/km4SwdOdZQxsMCp83wZlNibTGfIepIqGXpT_LZzNS2eWRlwCtI-qSKl8H04wETNdRfiVApljJA=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': 'People me Flori Gjini është programi që sjell njeriun e vërtetë dhe të zakonshëm, por me historinë e jashtëzakonshme. Histori të treguara nga vetë ata, ku gjithkush gjen një copëz...',
#    'viewCount': '35786',
#    'publishedTimeText': '16 hours ago',
#    'publishDate': '2024-10-15',
#    'publishedAt': '2024-10-15T00:00:00Z',
#    'lengthText': '32:15',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/ofhnqJWFuNI/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC6NHmfHzZVnpoyFc-GyhPtGJlLfw',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/ofhnqJWFuNI/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAklXmpoJSpBWU2F9DaOFTVdPslhw',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/ofhnqJWFuNI/mqdefault_6s.webp?du=3000&sqp=CIrRvbgG&rs=AOn4CLDgsXT95wia1bI6KbChcbBaM1tmTw',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'oFFdtWnZ5Jk',
#    'title': "World's Spiciest Cooking Challenge",
#    'channelTitle': 'Nick DiGiovanni',
#    'channelId': 'UCMyOj6fhvKFMjxUCp3b_3gA',
#    'channelHandle': '@NickDiGiovanni',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/flQNxMIkGvrAaublvNUp1l0MIkMjAeNq8q63SNI5Tc0rkRrF91Vp_SwWBIgpMDn7TjGeWUnuWg=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': "Loser has to eat the world's spiciest pepper. Watch to the end to see who it is!\n\nThanks to Sean + Esther + @FirstWeFeast for making this happen :)\n\nAnd thanks to all the following for helping...",
#    'viewCount': '2822255',
#    'publishedTimeText': '3 days ago',
#    'publishDate': '2024-10-13',
#    'publishedAt': '2024-10-13T00:00:00Z',
#    'lengthText': '25:38',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/oFFdtWnZ5Jk/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCzj-k42dCmMllXOlCdIhLNUTl5AQ',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/oFFdtWnZ5Jk/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDF5vlLGjSglaoeJemVtqH8lCfVxQ',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/oFFdtWnZ5Jk/mqdefault_6s.webp?du=3000&sqp=CKfbvbgG&rs=AOn4CLAiWgJTkJSkUETHtVm5M4Gu3AASiA',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'ZPRntiAheZs',
#    'title': 'Ed Sheeran, Bruno Mars, Dua Lipa, Adele, Maroon 5, Rihanna, The Weeknd - Pop music 2024',
#    'channelTitle': 'Dreamy Vibez Music',
#    'channelId': 'UCtPUoGZtitNshC8VYj2M4Cw',
#    'channelHandle': '@Dreamyvibezmusic-v3m',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/0FPHdkfmPCw57259928HPBQ9n8Gko3nWpPl9pLhI6IjV_GwbCihquz9hqMfRAD4Rlhk3khEu=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': 'Ed Sheeran, Bruno Mars, Dua Lipa, Adele, Maroon 5, Rihanna, The Weeknd - Pop music 2024\nEd Sheeran, Bruno Mars, Dua Lipa, Adele, Maroon 5, Rihanna, The Weeknd - Pop music 2024\nhttps://youtu.be/ZPRn...',
#    'viewCount': '631364',
#    'publishedTimeText': '3 weeks ago',
#    'publishDate': '2024-09-25',
#    'publishedAt': '2024-09-25T00:00:00Z',
#    'lengthText': '3:00:56',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/ZPRntiAheZs/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBPKSiBspaYg5BV6YnsX34pyq4FFg',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/ZPRntiAheZs/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCYppucxjdLbYpJwf9GiUKm_5NQVQ',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': None},
#   {'type': 'video',
#    'videoId': 'KIZD9VksMRw',
#    'title': "L'INTERA storia di Dragon Ball Super in 17 minuti",
#    'channelTitle': 'Capitano Toon',
#    'channelId': 'UCnRpZZ6zw51VkG-2F_30ZrA',
#    'channelHandle': '@CapitanoToon',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/X8sgM9-mYnht4C7NtTTlq5VnsErvlazzqZ_D3pwHOkttM04Gq2MnaI2Zg6GpFg2v9RW_bnn7ng=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': "Siete pronti per questo viaggio nella nostalgia nelle avventure di Goku e tutti i suoi amici nell'universo di Dragon Ball? \n\nDragon Ball é una delle opere più famose scritte da Akira Toriyama,...",
#    'viewCount': '50961',
#    'publishedTimeText': '7 days ago',
#    'publishDate': '2024-10-09',
#    'publishedAt': '2024-10-09T00:00:00Z',
#    'lengthText': '17:15',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/KIZD9VksMRw/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDPg9K0-U6NgRIN6Te38oWm0Ju5UQ',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/KIZD9VksMRw/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBgl083-K5evmDhACuYPCNjCA0izg',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/KIZD9VksMRw/mqdefault_6s.webp?du=3000&sqp=CKTKvbgG&rs=AOn4CLDLaVXkRcnqn5Y9bFGpWFae9HJAbw',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'jPD0s6KMFpk',
#    'title': 'JOHN WICK BALLERINA Trailer (4K ULTRA HD) NEW 2025',
#    'channelTitle': 'FilmSpot Trailer',
#    'channelId': 'UCWOSgEKGpS5C026lY4Y4KGw',
#    'channelHandle': '@filmspotofficial',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_kmdAl1l11SDP0ncAzoTmrsVGsbbyd5ioxP9CckxOlU88U=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': 'Official new movie trailer for John Wick Ballerina\n\nPlot : A young female assassin seeks revenge against the people who killed her family.\n\n\nFollow Us On Instagram : https://www.instagram.com/films...',
#    'viewCount': '2328592',
#    'publishedTimeText': '2 weeks ago',
#    'publishDate': '2024-10-02',
#    'publishedAt': '2024-10-02T00:00:00Z',
#    'lengthText': '2:34',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/jPD0s6KMFpk/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDg7HZN2_uPV9x2mSQ2ApypVFsgNg',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/jPD0s6KMFpk/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC4e4YNCx3MgWdlGzfArszvCG1Q5w',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/jPD0s6KMFpk/mqdefault_6s.webp?du=3000&sqp=CM_avbgG&rs=AOn4CLArukzz9shuwaREODwzbaBuPYqi9g',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': '10qFPJFZDLc',
#    'title': '6 Grandmas vs 1 Fake | Odd One Out (ft. Duncan Joseph)',
#    'channelTitle': 'Jubilee',
#    'channelId': 'UCJjSDX-jUChzOEyok9XYRJQ',
#    'channelHandle': '@jubilee',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/d4B1O0xCl6DJx6h1aZLgLWr4MO5h44f-0JL5qosNoejntdVRoW0OKVk1iLIN_65Ghz1wUF0LeiQ=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': 'Apply for our new series “AITA? irl” here: https://bit.ly/4eyMe1o\n\nHey you 👈 Wanna be in a Jubilee video? https://bit.ly/be-in-a-video\n\nLET’S BE FRIENDS\nInstagram: https://www.instagram.co...',
#    'viewCount': '2279874',
#    'publishedTimeText': '4 days ago',
#    'publishDate': '2024-10-12',
#    'publishedAt': '2024-10-12T00:00:00Z',
#    'lengthText': '22:32',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/10qFPJFZDLc/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCOoII6lOA6P6CRGIYft3CgaCnYPQ',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/10qFPJFZDLc/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBz6zG_V2LcTWNqddTvjSD8FXQZJA',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/10qFPJFZDLc/mqdefault_6s.webp?du=3000&sqp=CPnfvbgG&rs=AOn4CLBRF5mWcDOUTvvIzI2K3bpyaxvjhw',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'z2OtJLyn9xg',
#    'title': 'Il legame tra ultras e mafie: interessi milionari, ricatti ai grandi club e fiumi di droga.',
#    'channelTitle': 'Roberto Saviano Official',
#    'channelId': 'UCtgIlU49ppoBvEgDboD34Pg',
#    'channelHandle': '@robertosavianoofficial569',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_kQyCouKWz_NvyUmUTyP_fEuw6gwwcNlXwu0d2szu0Bfg=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': "In questo video per Fanpage.it racconto i profondi legami tra gli Ultras e i grandi club dopo l'operazione che ha decapitato le curve di Milan e Inter. Non solo biglietti e parcheggi gratuiti...",
#    'viewCount': '195703',
#    'publishedTimeText': '5 days ago',
#    'publishDate': '2024-10-11',
#    'publishedAt': '2024-10-11T00:00:00Z',
#    'lengthText': '13:49',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/z2OtJLyn9xg/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAlYIU4T30lTwpPmdydipgBCrLJdg',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/z2OtJLyn9xg/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC4dFChAdURkYqymIDWwceY_9GlHQ',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/z2OtJLyn9xg/mqdefault_6s.webp?du=3000&sqp=CIC4vbgG&rs=AOn4CLBIInSbjSbadmCoJws5_E6s1wP_5Q',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'eTlDGsJ3Gos',
#    'title': 'Man Builds DIY ANTI-RAIN Motorcycle | Start to Finish by @meanwhileinthegarage',
#    'channelTitle': 'Quantum Tech HD',
#    'channelId': 'UC4Tklxku1yPcRIH0VVCKoeA',
#    'channelHandle': '@QuantumTech',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_k3NnB8ZHlF_aJsehVatpLju5F3A59pwbtqwJVV2i9Tiog=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': 'Come with us inside the workshop of Meanwhile in the Garage, where an ordinary Yamaha YZF1000 R1 undergoes a groundbreaking transformation. The goal? To turn this high-performance sports bike...',
#    'viewCount': '7038326',
#    'publishedTimeText': '5 days ago',
#    'publishDate': '2024-10-11',
#    'publishedAt': '2024-10-11T00:00:00Z',
#    'lengthText': '16:31',
#    'thumbnail': [{'url': 'https://i9.ytimg.com/vi/eTlDGsJ3Gos/hq720_custom_2.jpg?sqp=CKznvbgG-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCWyVpA0gzk_wV4xc-5MztdIEBiog',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i9.ytimg.com/vi/eTlDGsJ3Gos/hq720_custom_2.jpg?sqp=CKznvbgG-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDj48sQ0NBNBcAEYSWa-w9CG8WXEw',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/eTlDGsJ3Gos/mqdefault_6s.webp?du=3000&sqp=COfgvbgG&rs=AOn4CLBQ46uvzrV8uFbFyHmJ0VQbazglBA',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'u9pul0_hmFY',
#    'title': 'BLUR REACTION UN GIORNO NELLA VITA DI CRISTIANO RONALDO con MARZA e MANUXO! 😂',
#    'channelTitle': 'SdrogoGoat',
#    'channelId': 'UCNMf7vK1y9r0klbNeIDf74A',
#    'channelHandle': '@SdrogoGoat',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/aYPBAoclQctE2cZFhXPiPp8aPVii50cfEVV6IpqaVnG7K7hUWRAw35HSEdbn5Xhp0ZXFfWnZwg=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': '🔔 ISCRIVITI E ATTIVA LA CAMPANELLA 🔔\nScopri tutte le novità presenti nel mondo dello streaming, non perderti nessuna reaction o notizia importante dei tuoi creator preferiti. Ci saranno...',
#    'viewCount': '219717',
#    'publishedTimeText': '2 weeks ago',
#    'publishDate': '2024-10-02',
#    'publishedAt': '2024-10-02T00:00:00Z',
#    'lengthText': '18:08',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/u9pul0_hmFY/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLD4JZTjLGPqfY5niRPXF7UppABSgA',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/u9pul0_hmFY/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCLGfbXuwHoIGmKjGfUkAIyVAZpyw',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/u9pul0_hmFY/mqdefault_6s.webp?du=3000&sqp=CPjmvbgG&rs=AOn4CLCj2v-cCxGo-X-ztJEhkTM3-JTu9A',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': '0RHTvOPhrdU',
#    'title': 'تلميع وتنظيف الجلد الطبيعي المدو#𝐒𝐏𝟓𝟎𝟓𝟏𝟑𝟗',
#    'channelTitle': 'حكايات واقعيه',
#    'channelId': 'UClouVJoyL_v-YcUDXvX-3Mw',
#    'channelHandle': '@%D8%AD%D9%83%D8%A7%D9%8A%D8%A7%D8%AA%D9%88%D8%A7%D9%82%D8%B9%D9%8A%D9%87-%D9%824%D8%B4',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/i-UGq_BekleoysEZ_BtBAB6peVltygonZQIiM3AE3HmsecAoZZVECGjXuVx9dj3ipN9YJLizE1E=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': '',
#    'viewCount': '39481',
#    'publishedTimeText': '9 hours ago',
#    'publishDate': '2024-10-15',
#    'publishedAt': '2024-10-15T00:00:00Z',
#    'lengthText': '37:05',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/0RHTvOPhrdU/hqdefault.jpg?sqp=-oaymwEcCOADEI4CSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC2zQJvSW2IfHBPA-Ksu8zQdxfwnA',
#      'width': 480,
#      'height': 270}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/0RHTvOPhrdU/mqdefault_6s.webp?du=3000&sqp=COvhvbgG&rs=AOn4CLDBP5Q3RnZXxeTkjG1RxYZ9KQpllw',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'RDNx7Yf3cBk',
#    'title': 'Il RISORGIMENTO ITALIANO (1815-1861)',
#    'channelTitle': 'La Storia sul Tubo',
#    'channelId': 'UCaQOdL1Axokju0j3JDrJYqA',
#    'channelHandle': '@LaStoriaSulTubo',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/EC5XStDriXtAClrqyk4NL1hsXsfoCfrrc5d3RwNNrr06pv0Fv9Dzk9_f2cx2sWCQh9YGxGjLuA=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': "► ABBONATI QUI:\nhttps://steadyhq.com/it/lastoriasultubo/about\n\nNapoleone ha lasciato un'eredità significativa per l'Italia, alimentando l'idea di un'unità nazionale. I moti piemontesi del...",
#    'viewCount': '154235',
#    'publishedTimeText': '5 months ago',
#    'publishDate': '2024-05-16',
#    'publishedAt': '2024-05-16T00:00:00Z',
#    'lengthText': '1:28:54',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/RDNx7Yf3cBk/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAv2YMkGYTsFxkUfufUXrqOW0v2Zg',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/RDNx7Yf3cBk/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLD920T6l9XIIJQf-oMSKbee9pFdbg',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/RDNx7Yf3cBk/mqdefault_6s.webp?du=3000&sqp=CNbZvbgG&rs=AOn4CLDOKAjpAoc-2Ib_vWe1KfCwgWw5HA',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'HuherPkRFZA',
#    'title': "È l'ora delle AUDIZIONI più DIVERTENTI di X FACTOR 2024 (Compilation)",
#    'channelTitle': 'X Factor Italia',
#    'channelId': 'UC2WY0Kkfhi3sm4P25MnjhpA',
#    'channelHandle': '@xfactoritalia',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/yY1PbEeEJENqsHrvgTSviYLwxyDLnI0ZfV2yiOGn8NAXOic001VxQUE6dcJVhjirTcV0XnASyw=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': "Ridendo e scherzando siamo giunti al termine di queste Audizioni. Abbiamo raccolto tutte le esibizioni più memorabili e siamo pronti a scoprire cos'altro ha in serbo per noi questo #XF2024...",
#    'viewCount': '830111',
#    'publishedTimeText': '2 weeks ago',
#    'publishDate': '2024-10-02',
#    'publishedAt': '2024-10-02T00:00:00Z',
#    'lengthText': '32:40',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/HuherPkRFZA/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLD8MfN7qGBk4BpfVpKkbw-aoy0vGQ',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/HuherPkRFZA/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAoi5pwAINbWVQZ92W-pkFiMZjX9Q',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/HuherPkRFZA/mqdefault_6s.webp?du=3000&sqp=COC7vbgG&rs=AOn4CLDlXeh9ygFBw-0Yi_6nISELJeQ5uw',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'ms-Tr0GbVAY',
#    'title': 'Study with Korean law student for 2 hours! [Study with me]',
#    'channelTitle': '댕은',
#    'channelId': 'UC-kML0CG86wg2u7BggA_rDw',
#    'channelHandle': '@springofyoo',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/tgJOesWFvAu0FRp6CGNiPbPMc7OmBntR0mHQ-MeZKT0p4nwdJsxP82oVynTom7WPnuvuPvz0ag=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': '오늘도 공부뿐!!!! 같이 2시간 동안 공부해요! 저는 지난 2주에 걸쳐서 시험 4개를 끝냈고 이제 2개가 남았네요... 대체 언제 끝나는 건지! \n와중에...',
#    'viewCount': '1320976',
#    'publishedTimeText': '10 months ago',
#    'publishDate': '2023-12-16',
#    'publishedAt': '2023-12-16T00:00:00Z',
#    'lengthText': '2:10:59',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/ms-Tr0GbVAY/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAfGMuf0hnU_nkYN_ZDsNC2C3RfNQ',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/ms-Tr0GbVAY/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCflzurjh6P0IXhuuh0q4QmZr1iMw',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/ms-Tr0GbVAY/mqdefault_6s.webp?du=3000&sqp=CNTnvbgG&rs=AOn4CLAiT9DDTdr089LUoHlCsmBgI54rUQ',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'YUaSVFXTHlk',
#    'title': 'Alone: Relaxing Ambient SPACE Music for Being Alone on Distant Planets',
#    'channelTitle': 'Futurescapes - Sci Fi Ambience',
#    'channelId': 'UCDyghjHud0sexPHxs5qPXUQ',
#    'channelHandle': '@Futurescapes-SciFiAmbience',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/HNfqpsBqXGLphKLwmHcGMHqDr5RZuV41qph0ZbDJkJb1lVOZ0K9mdohpWr9CJG1Scwvnizx1zeY=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': "As you gaze out towards the vast expanse of space spread before you, your mind slows and empties of life's concerns. Stars of distant worlds glisten and glitter across the sky's celestial tapestry,...",
#    'viewCount': '445031',
#    'publishedTimeText': '1 month ago',
#    'publishDate': '2024-09-16',
#    'publishedAt': '2024-09-16T00:00:00Z',
#    'lengthText': '1:00:01',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/YUaSVFXTHlk/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDQ45Irm4uBd3dozF4CtiIkSB6EiQ',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/YUaSVFXTHlk/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDzm5rRi7pqeHC65ElarIzeovCPZA',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': None},
#   {'type': 'video',
#    'videoId': 'uU3AIBmXF1o',
#    'title': 'Tom und Jerry auf Deutsch | Klassischer Cartoon 115 | WB Kids',
#    'channelTitle': 'WB Kids Deutschland',
#    'channelId': 'UCrev-dqCk0e1ig6HGZVB6Ow',
#    'channelHandle': '@WBKidsDeutschland',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/R297M7jAVBV8_1NIsybn59l5XIvTVygHhrgu8F7iZCblqS-kHRGDWwDlOkR3Lgt13fHpYVvb=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': 'Geh auf wilde Verfolgungsjagd mit Tom und Jerry, ihrem Erzfeind Spike und dem Straßenkater Butch sowie dem unartigen Entlein.\n\nWB Kids ist das Heim all eurer Lieblingsclips! Mit Charakteren...',
#    'viewCount': '141312593',
#    'publishedTimeText': '3 years ago',
#    'publishDate': '2021-10-16',
#    'publishedAt': '2021-10-16T00:00:00Z',
#    'lengthText': '22:49',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/uU3AIBmXF1o/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAZfjTaiuF0Aqo3rTqDev4d4C8UZA',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/uU3AIBmXF1o/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBngXdZQXZj4KsCpERZ-QKqKvSEpQ',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/uU3AIBmXF1o/mqdefault_6s.webp?du=3000&sqp=CLalvbgG&rs=AOn4CLDXxWAFXGPaZx3PbA7HrBlklDNPZQ',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'yjaJzBySYc4',
#    'title': "avventura onirica nell'ESTREMO NORD giapponese",
#    'channelTitle': 'Nicolò Balini',
#    'channelId': 'UCjMIGhRExEB-Q6ZyEr1gBeA',
#    'channelHandle': '@safariumano',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/Jsv3ZEVcCIHIJabfcFlwSiJ5_ZxjM5gala-tKUH609hTgGz8vrs4WArGVhRKN-xPuD6ulEbZFfE=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': "fatto Capo Sata, andava fatto anche Capo Soya, l'estremo nord del Giappone! il punto più a Nord dell'Hokkaido dal quale si riesce a vedere la Russia 🇯🇵🇷🇺\n\n🍋 Visita il link http://ww...",
#    'viewCount': '342928',
#    'publishedTimeText': '8 days ago',
#    'publishDate': '2024-10-08',
#    'publishedAt': '2024-10-08T00:00:00Z',
#    'lengthText': '33:01',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/yjaJzBySYc4/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCNEA_h0g_D7dQOMc1aZEgTNb6y5w',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/yjaJzBySYc4/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAijCdODrTs1EnITQwDmsNCPKwWiw',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/yjaJzBySYc4/mqdefault_6s.webp?du=3000&sqp=CNq1vbgG&rs=AOn4CLDxbczmGyvK-968bJeinuAajVSrGw',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'YpZLZxTHuRE',
#    'title': "Best Classic Rock Songs 70s 80s 90s 🔥 Guns N' Roses, Aerosmith, Bon Jovi, Metallica, Queen, ACDC, U2",
#    'channelTitle': 'Classic Rock Music',
#    'channelId': 'UCi2jbVwpJ-ydjXDP06Mr0sA',
#    'channelHandle': '@classicrockmusic.2',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/wTrep5i5rSzEJTTm0HNjeHRV2xCXio8OwvaHXHvpRJyjFYCzmYOVJ9UUeHaZPaO2W2rs8kh8YFM=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': 'https://youtu.be/YpZLZxTHuRE\n---------------------------------------------------------------\n💙 Thanks for Watching! 💙\nIf you enjoyed the video, please give us a thumbs up and share it...',
#    'viewCount': '481505',
#    'publishedTimeText': '2 weeks ago',
#    'publishDate': '2024-10-02',
#    'publishedAt': '2024-10-02T00:00:00Z',
#    'lengthText': '3:10:48',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/YpZLZxTHuRE/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBBasIKMr6xmKflvlD2r8bqQGmR2A',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/YpZLZxTHuRE/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA1kvqZhxklwGCAWbzE2Z37ZTqGgg',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': None},
#   {'type': 'video',
#    'videoId': 'elDzoxjc9XQ',
#    'title': 'Hitler in Colour (4K WW2 Documentary)',
#    'channelTitle': 'Best Documentary',
#    'channelId': 'UCmOCpBKeoBPp-HwarhIBA2g',
#    'channelHandle': '@BestDoc',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_kq7HXenRO6FYNetDE_v1upk33Y8JKNX_k5woUzbL8tH3o=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': "Documentary using only original colour footage charts the 12 years from Adolf Hitler's rise to power to the fall of Berlin in 1945. Complemented by eyewitness material, tracks the dramatic...",
#    'viewCount': '13150366',
#    'publishedTimeText': '6 months ago',
#    'publishDate': '2024-04-16',
#    'publishedAt': '2024-04-16T00:00:00Z',
#    'lengthText': '1:10:44',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/elDzoxjc9XQ/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBIDFa6C14W0ePPwTjTK7qCvGjCbQ',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/elDzoxjc9XQ/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCQ3l4W8Em5zF3oEk-rcFPqo82WYw',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/elDzoxjc9XQ/mqdefault_6s.webp?du=3000&sqp=CKy1vbgG&rs=AOn4CLAJw_gXuuRWj8ePxDrDsQrs6819Iw',
#      'width': 320,
#      'height': 180}]},
#   {'type': 'video',
#    'videoId': 'mHZRFs-faX8',
#    'title': 'Cooking Curry During College Lecture!',
#    'channelTitle': 'Fique ',
#    'channelId': 'UCElqQlsab8XmZsKypLYSzEQ',
#    'channelHandle': '@fiqueayub',
#    'channelThumbnail': [{'url': 'https://yt3.ggpht.com/6wlXMxPEtPbwtbHg8EUL8VTLaUYbqqlipsoIxpAnXVriCdC8wyuJrBj9RLUtwK2Kh4yadifk=s68-c-k-c0x00ffffff-no-rj',
#      'width': 68,
#      'height': 68}],
#    'description': 'Love you guys thank you so much for the support!\n\nfollow my socials: \n\nInstagram -   / fiqueayub  \nSnapchat - fiqueayub33\n\nbusiness inquiries - fiqueayub33@gmail.com',
#    'viewCount': '318946',
#    'publishedTimeText': '3 days ago',
#    'publishDate': '2024-10-13',
#    'publishedAt': '2024-10-13T00:00:00Z',
#    'lengthText': '14:17',
#    'thumbnail': [{'url': 'https://i.ytimg.com/vi/mHZRFs-faX8/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAt6jazIai5gJwOpE8Ntj0wz1AkGg',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/mHZRFs-faX8/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDa88vkSyaQprNtiGnX542uroG4uw',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': [{'url': 'https://i.ytimg.com/an_webp/mHZRFs-faX8/mqdefault_6s.webp?du=3000&sqp=CMLfvbgG&rs=AOn4CLA8APRjsG7LVS3hI0Yk34blibYpeQ',
#      'width': 320,
#      'height': 180}]}],
#  'msg': ''}

# %%
url = "https://yt-api.p.rapidapi.com/home"

querystring = {"geo":"IT"}

headers = {
	"x-rapidapi-key": "d31f7e5962msh64f6070990dee3dp1df11fjsnb7da1f2108ba",
	"x-rapidapi-host": "yt-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
IT_hf = response.json()
IT_hf = IT_hf['data']
df_IT_hf = pd.DataFrame(IT_hf)

df_IT_hf = df_IT_hf.drop(columns = [
    'videoId',
    'channelId',
    'channelTitle',
    'channelThumbnail',
    'publishedTimeText',
    'publishDate',
    'thumbnail',
    'richThumbnail',
    'channelId',
    'channelHandle',
    'publishedAt',
    'subtitle',
    'data'])
df_IT_hf['country'] = 'IT'
df_IT_hf['date'] = pd.Timestamp.now().date() # add date column 
df_IT_hf.to_csv('home feed 7 IT.csv')
df_IT_hf.head(3)
# Out:
#              type                                              title  \
# 0           video  Warm Morning Jazz Music at Fall Coffee Shop Am...
# 1  shorts_listing                                             Shorts
# 2   video_listing                                           Trending
#
#                                          description viewCount lengthText  \
# 0  Warm Morning Jazz Music at Fall Coffee Shop Am...    193622   11:54:57
# 1                                                NaN       NaN        NaN
# 2                                                NaN       NaN        NaN
#
#   country        date
# 0      IT  2024-10-16
# 1      IT  2024-10-16
# 2      IT  2024-10-16

# %% [markdown]
# ## Norway

# %% [markdown]
# TRENDING

# %%
url = "https://yt-api.p.rapidapi.com/trending"

querystring = {"geo":"NO"}

headers = {
	"x-rapidapi-key": "d31f7e5962msh64f6070990dee3dp1df11fjsnb7da1f2108ba",
	"x-rapidapi-host": "yt-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
NO = response.json()
NO = NO['data']
df_NO = pd.DataFrame(NO)
df_NO = df_NO.drop(columns = [
    'videoId',
    'channelId',
    'channelHandle',
    'channelThumbnail',
    'publishedTimeText',
    'publishedAt',
    'thumbnail',
    'richThumbnail',
    'data'])
    
df_NO['country'] = 'NO'
df_NO['date'] = pd.Timestamp.now().date() # add date column 
df_NO.to_csv('trending 7 NO.csv')

# %% [markdown]
# HOME FEED

# %%
NO_hf
# Out:
# {'error': 'Retry', 'code': '403'}

# %%
url = "https://yt-api.p.rapidapi.com/home"

querystring = {"geo":"NO"}

headers = {
	"x-rapidapi-key": "d31f7e5962msh64f6070990dee3dp1df11fjsnb7da1f2108ba",
	"x-rapidapi-host": "yt-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
NO_hf = response.json()
NO_hf = NO_hf['data']
df_NO_hf = pd.DataFrame(NO_hf)

df_NO_hf = df_NO_hf.drop(columns = [
    'videoId',
    'channelId',
    'channelTitle',
    'channelThumbnail',
    'publishedTimeText',
    'publishDate',
    'thumbnail',
    'richThumbnail',
    'channelId',
    'channelHandle',
    'publishedAt',
    'subtitle',
    'data'])
df_NO_hf['country'] = 'NO'
df_NO_hf['date'] = pd.Timestamp.now().date() # add date column 
df_NO_hf.to_csv('home feed 7 NO.csv')
df_NO_hf.head(3)
# Out:
#              type                                              title  \
# 0           video  Warm Morning Jazz Music at Fall Coffee Shop Am...
# 1  shorts_listing                                             Shorts
# 2   video_listing                                           Trending
#
#                                          description viewCount lengthText  \
# 0  Warm Morning Jazz Music at Fall Coffee Shop Am...    193622   11:54:57
# 1                                                NaN       NaN        NaN
# 2                                                NaN       NaN        NaN
#
#   isLive badges country        date
# 0    NaN    NaN      NO  2024-10-16
# 1    NaN    NaN      NO  2024-10-16
# 2    NaN    NaN      NO  2024-10-16

# %% [markdown]
# ## Canada

# %% [markdown]
# TRENDING

# %%
url = "https://yt-api.p.rapidapi.com/trending"

querystring = {"geo":"CA"}

headers = {
	"x-rapidapi-key": "d31f7e5962msh64f6070990dee3dp1df11fjsnb7da1f2108ba",
	"x-rapidapi-host": "yt-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
CA = response.json()
CA = CA['data']
df_CA = pd.DataFrame(CA)
df_CA = df_CA.drop(columns = [
    'videoId',
    'channelId',
    'channelHandle',
    'channelThumbnail',
    'publishedTimeText',
    'publishedAt',
    'thumbnail',
    'richThumbnail',
    'data'])
    
df_CA['country'] = 'CA'
df_CA['date'] = pd.Timestamp.now().date() # add date column 
df_CA.to_csv('trending 7 CA.csv')

# %% [markdown]
# HOME FEED

# %%
url = "https://yt-api.p.rapidapi.com/home"

querystring = {"geo":"CA"}

headers = {
	"x-rapidapi-key": "d31f7e5962msh64f6070990dee3dp1df11fjsnb7da1f2108ba",
	"x-rapidapi-host": "yt-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
CA_hf = response.json()
CA_hf = CA_hf['data']
df_CA_hf = pd.DataFrame(CA_hf)

df_CA_hf = df_CA_hf.drop(columns = [
    'videoId',
    'channelId',
    'channelTitle',
    'channelThumbnail',
    'publishedTimeText',
    'publishDate',
    'thumbnail',
    'richThumbnail',
    'channelId',
    'channelHandle',
    'publishedAt',
    'subtitle',
    'data'])
df_CA_hf['country'] = 'CA'
df_CA_hf['date'] = pd.Timestamp.now().date() # add date column 
df_CA_hf.to_csv('home feed 7 CA.csv')
df_CA_hf.head(3)
# Out:
#              type                                              title  \
# 0           video  Heavy Rain On Roof For Deep Sleep & Insomnia R...
# 1  shorts_listing                                             Shorts
# 2   video_listing                                           Trending
#
#                                          description viewCount lengthText  \
# 0  HEAVY RAIN on Roof for Deep Sleep & Insomnia R...    718803   11:55:00
# 1                                                NaN       NaN        NaN
# 2                                                NaN       NaN        NaN
#
#   isLive badges country        date
# 0    NaN    NaN      CA  2024-10-16
# 1    NaN    NaN      CA  2024-10-16
# 2    NaN    NaN      CA  2024-10-16

# %% [markdown]
# ## merge cvs

# %%
# day 1
df1_T_US = pd.read_csv('trending 1 US.csv')
df1_T_ES = pd.read_csv('trending 1 ES.csv')
df1_T_FR = pd.read_csv('trending 1 FR.csv')
df1_T_IT = pd.read_csv('trending 1 IT.csv')
df1_T_NO = pd.read_csv('trending 1 NO.csv')
df1_T_CA = pd.read_csv('trending 1 CA.csv')

df1_HF_US = pd.read_csv('home feed 1 US.csv')
df1_HF_ES = pd.read_csv('home feed 1 ES.csv')
df1_HF_FR = pd.read_csv('home feed 1 FR.csv')
df1_HF_IT = pd.read_csv('home feed 1 IT.csv')
df1_HF_NO = pd.read_csv('home feed 1 NO.csv')
df1_HF_CA = pd.read_csv('home feed 1 CA.csv')

# Day 2
df2_T_US = pd.read_csv('trending 2 US.csv')
df2_T_ES = pd.read_csv('trending 2 ES.csv')
df2_T_FR = pd.read_csv('trending 2 FR.csv')
df2_T_IT = pd.read_csv('trending 2 IT.csv')
df2_T_NO = pd.read_csv('trending 2 NO.csv')
df2_T_CA = pd.read_csv('trending 2 CA.csv')

df2_HF_US = pd.read_csv('home feed 2 US.csv')
df2_HF_ES = pd.read_csv('home feed 2 ES.csv')
df2_HF_FR = pd.read_csv('home feed 2 FR.csv')
df2_HF_IT = pd.read_csv('home feed 2 IT.csv')
df2_HF_NO = pd.read_csv('home feed 2 NO.csv')
df2_HF_CA = pd.read_csv('home feed 2 CA.csv')

## day 3
df3_T_US = pd.read_csv('trending 3 US.csv')
df3_T_ES = pd.read_csv('trending 3 ES.csv')
df3_T_FR = pd.read_csv('trending 3 FR.csv')
df3_T_IT = pd.read_csv('trending 3 IT.csv')
df3_T_NO = pd.read_csv('trending 3 NO.csv')
df3_T_CA = pd.read_csv('trending 3 CA.csv')

df3_HF_US = pd.read_csv('home feed 3 US.csv')
df3_HF_ES = pd.read_csv('home feed 3 ES.csv')
df3_HF_FR = pd.read_csv('home feed 3 FR.csv')
df3_HF_IT = pd.read_csv('home feed 3 IT.csv')
df3_HF_NO = pd.read_csv('home feed 3 NO.csv')
df3_HF_CA = pd.read_csv('home feed 3 CA.csv')

## day 4
df4_T_US = pd.read_csv('trending 4 US.csv')
df4_T_ES = pd.read_csv('trending 4 ES.csv')
df4_T_FR = pd.read_csv('trending 4 FR.csv')
df4_T_IT = pd.read_csv('trending 4 IT.csv')
df4_T_NO = pd.read_csv('trending 4 NO.csv')
df4_T_CA = pd.read_csv('trending 4 CA.csv')

df4_HF_US = pd.read_csv('home feed 4 US.csv')
df4_HF_ES = pd.read_csv('home feed 4 ES.csv')
df4_HF_FR = pd.read_csv('home feed 4 FR.csv')
df4_HF_IT = pd.read_csv('home feed 4 IT.csv')
df4_HF_NO = pd.read_csv('home feed 4 NO.csv')
df4_HF_CA = pd.read_csv('home feed 4 CA.csv')

## day 5
df5_T_US = pd.read_csv('trending 5 US.csv')
df5_T_ES = pd.read_csv('trending 5 ES.csv')
df5_T_FR = pd.read_csv('trending 5 FR.csv')
df5_T_IT = pd.read_csv('trending 5 IT.csv')
df5_T_NO = pd.read_csv('trending 5 NO.csv')
df5_T_CA = pd.read_csv('trending 5 CA.csv')

df5_HF_US = pd.read_csv('home feed 5 US.csv')
df5_HF_ES = pd.read_csv('home feed 5 ES.csv')
df5_HF_FR = pd.read_csv('home feed 5 FR.csv')
df5_HF_IT = pd.read_csv('home feed 5 IT.csv')
df5_HF_NO = pd.read_csv('home feed 5 NO.csv')
df5_HF_CA = pd.read_csv('home feed 5 CA.csv')

## day 6
df6_T_US = pd.read_csv('trending 6 US.csv')
df6_T_ES = pd.read_csv('trending 6 ES.csv')
df6_T_FR = pd.read_csv('trending 6 FR.csv')
df6_T_IT = pd.read_csv('trending 6 IT.csv')
df6_T_NO = pd.read_csv('trending 6 NO.csv')
df6_T_CA = pd.read_csv('trending 6 CA.csv')

df6_HF_US = pd.read_csv('home feed 6 US.csv')
df6_HF_ES = pd.read_csv('home feed 6 ES.csv')
df6_HF_FR = pd.read_csv('home feed 6 FR.csv')
df6_HF_IT = pd.read_csv('home feed 6 IT.csv')
df6_HF_NO = pd.read_csv('home feed 6 NO.csv')
df6_HF_CA = pd.read_csv('home feed 6 CA.csv')

## day 7
df7_T_US = pd.read_csv('trending 7 US.csv')
df7_T_ES = pd.read_csv('trending 7 ES.csv')
df7_T_FR = pd.read_csv('trending 7 FR.csv')
df7_T_IT = pd.read_csv('trending 7 IT.csv')
df7_T_NO = pd.read_csv('trending 7 NO.csv')
df7_T_CA = pd.read_csv('trending 7 CA.csv')

df7_HF_US = pd.read_csv('home feed 7 US.csv')
df7_HF_ES = pd.read_csv('home feed 7 ES.csv')
df7_HF_FR = pd.read_csv('home feed 7 FR.csv')
df7_HF_IT = pd.read_csv('home feed 7 IT.csv')
df7_HF_NO = pd.read_csv('home feed 7 NO.csv')
df7_HF_CA = pd.read_csv('home feed 7 CA.csv')

# %%
#concat the first and second day of data - Trending
DF_T_Total = pd.concat([df1_T_US, df1_T_ES, df1_T_FR, df1_T_IT, df1_T_NO, df1_T_CA, df2_T_US, df2_T_ES, df2_T_FR, df2_T_IT, df2_T_NO, df2_T_CA, df3_T_US, df3_T_ES, df3_T_FR, df3_T_IT, df3_T_NO, df3_T_CA, df4_T_US, df4_T_ES, df4_T_FR, df4_T_IT, df4_T_NO, df4_T_CA, df5_T_US, df5_T_ES, df5_T_FR, df5_T_IT, df5_T_NO, df5_T_CA, df6_T_US, df6_T_ES, df6_T_FR, df6_T_IT, df6_T_NO, df6_T_CA, df7_T_US, df7_T_ES, df7_T_FR, df7_T_IT, df7_T_NO, df7_T_CA])

#concat the first and second day of data - HomeFeed
DF_HF_Total = pd.concat([df1_HF_US, df1_HF_ES, df1_HF_FR, df1_HF_IT, df1_HF_NO, df1_HF_CA, df2_HF_US, df2_HF_ES, df2_HF_FR, df2_HF_IT, df2_HF_NO, df2_HF_CA, df3_HF_US, df3_HF_ES, df3_HF_FR, df3_HF_IT, df3_HF_NO, df3_HF_CA, df4_HF_US, df4_HF_ES, df4_HF_FR, df4_HF_IT, df4_HF_NO, df4_HF_CA, df5_HF_US, df5_HF_ES, df5_HF_FR, df5_HF_IT, df5_HF_NO, df5_HF_CA, df6_HF_US, df6_HF_ES, df6_HF_FR, df6_HF_IT, df6_HF_NO, df6_HF_CA, df7_HF_US, df7_HF_ES, df7_HF_FR, df7_HF_IT, df7_HF_NO, df7_HF_CA])

# %% [markdown]
# ## CLEANING

# %%
##---HOME FEED---##
#remove unwanted columns
DF_HF_Total = DF_HF_Total.drop(columns = [
    'isLive', #too many Null values
    'Unnamed: 0', # no need for this column
    'badges',
    'type',
    'description'
]) 

#rename columns
DF_HF_Total.rename(columns={
    'viewCount' : 'views',
    'lengthText': 'HH:MM:SS'
}, inplace=True)

# Changing date
DF_HF_Total.loc[DF_HF_Total['date'].str.contains('2024-10-10', case=False, na=False), 'date'] = 'October 10'
DF_HF_Total.loc[DF_HF_Total['date'].str.contains('2024-10-11', case=False, na=False), 'date'] = 'October 11'
DF_HF_Total.loc[DF_HF_Total['date'].str.contains('2024-10-12', case=False, na=False), 'date'] = 'October 12'
DF_HF_Total.loc[DF_HF_Total['date'].str.contains('2024-10-13', case=False, na=False), 'date'] = 'October 13'
DF_HF_Total.loc[DF_HF_Total['date'].str.contains('2024-10-14', case=False, na=False), 'date'] = 'October 14'
DF_HF_Total.loc[DF_HF_Total['date'].str.contains('2024-10-15', case=False, na=False), 'date'] = 'October 15'
DF_HF_Total.loc[DF_HF_Total['date'].str.contains('2024-10-16', case=False, na=False), 'date'] = 'October 16'


##---TRENDING---##
#Remove unwanted columns
DF_T_Total = DF_T_Total.drop(columns = [
    'Unnamed: 0',
    'publishDate',
    'channelTitle',
    'type',
    'description'
])

#Rename columns
DF_T_Total.rename(columns={
    'viewCount' : 'views',
    'lengthText': 'HH:MM:SS'
}, inplace=True)

# Changing dates
DF_T_Total.loc[DF_T_Total['date'].str.contains('2024-10-10', case=False, na=False), 'date'] = 'October 10'
DF_T_Total.loc[DF_T_Total['date'].str.contains('2024-10-11', case=False, na=False), 'date'] = 'October 11'
DF_T_Total.loc[DF_T_Total['date'].str.contains('2024-10-12', case=False, na=False), 'date'] = 'October 12'
DF_T_Total.loc[DF_T_Total['date'].str.contains('2024-10-13', case=False, na=False), 'date'] = 'October 13'
DF_T_Total.loc[DF_T_Total['date'].str.contains('2024-10-14', case=False, na=False), 'date'] = 'October 14'
DF_T_Total.loc[DF_T_Total['date'].str.contains('2024-10-15', case=False, na=False), 'date'] = 'October 15'
DF_T_Total.loc[DF_T_Total['date'].str.contains('2024-10-16', case=False, na=False), 'date'] = 'October 16'

# %%
#Standarize time to -> HH:MM:SS
def fix_time(time_str):
    if pd.isna(time_str):
        return np.nan
    time_parts = time_str.split(':')

    # normalise to HH:MM:SS
    if len(time_parts) == 2: #MM:SS
        hours = '00'
        minutes, seconds = time_parts
    elif len(time_parts) ==3: #HH:MM:SS
        hours, minutes, seconds = time_parts
    else:
        return np.nan

    #make sure all parts are 2 digits
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02}"

DF_HF_Total['HH:MM:SS'] = DF_HF_Total['HH:MM:SS'].apply(fix_time)
DF_T_Total['HH:MM:SS'] = DF_T_Total['HH:MM:SS'].apply(fix_time)

# %%
# Fill NaN values in 'views' with mean
views_mean = round(DF_HF_Total.views.mean(),2)
DF_HF_Total['views'] = DF_HF_Total['views'].fillna(views_mean)

views_mean = round(DF_T_Total.views.mean(),2)
DF_T_Total['views'] = DF_T_Total['views'].fillna(views_mean)

# %%
#Add colum for HomeFeed or Trending 
DF_HF_Total['data_from'] = 'HF'
DF_T_Total['data_from'] = 'T'

# %%
DF_FINAL = pd.concat([DF_HF_Total, DF_T_Total])
DF_FINAL.drop_duplicates(inplace=True)
DF_FINAL.shape
# Out:
# (3042, 6)

# %%
DF_FINAL.isna().sum()
# Out:
# title        0
# views        0
# HH:MM:SS     0
# country      0
# date         0
# data_from    0
# dtype: int64

# %%
DF_FINAL.dropna(subset=["HH:MM:SS"], inplace=True) #to drop 'NaN' from 'HH:MM:SS' column

# %%
# range of time
def time_range(time):
    for i in time:
        if time <= '00:00:59':
            return '< 1 min'
        elif time <= '00:01:59':
            return '< 2 min'
        elif time <= '00:02:59':
            return '< 3 min'
        elif time <= '00:03:59':
            return '< 4 min'
        elif time <= '00:04:59':
            return '< 5 min'
        elif time <= '00:09:59':
            return '< 10 min'
        elif time <= '00:19:59':
            return '< 20 min'
        elif time <= '00:29:59':
            return '< 30 min'
        elif time <= '00:39:59':
            return '< 40 min'
        elif time <= '00:49:59':
            return '< 50 min'
        elif time <= '00:59:59':
            return '< 1 hour'
        elif time <= '01:14:59':
            return '< 1 hour 15 minutues'
        elif time <= '01:29:59':
            return '< 1 hour 30 minutues'
        elif time <= '01:44:59':
            return '< 1 hour 45 minutues'
        elif time <= '01:59:59':
            return '< 2 hours'
        elif time <= '02:29:59':
            return '< 2 hours 30 minutes'
        elif time <= '02:59:59':
            return '< 3 hours'
        elif time <= '03:59:59':
            return '< 4 hours'
        else:
            return '> 4 hours'

# %%
# Turn lenght video 'HH:MM:SS' into seconds
def time_to_sec (time_str):
    hours, minutes, seconds = map(int, time_str.split(':'))
    total_sec = hours*3600 + minutes*60 + seconds
    return total_sec

# Turns seconds into HH:MM:SS
def hh_mm_ss(sec):
    hours = int(sec//3600) #gets whole hour
    rem_sec = total_sec%3600 #gets remaining seconds
    min = int(rem_sec//60) #gets the minutes
    sec = int(rem_sec%60) #gets remaining seconds

    return f"{hours:02}:{min:02}:{sec:02}"

# %%
DF_FINAL['time'] = DF_FINAL['HH:MM:SS'].apply(time_range) #create new column with range of time
DF_FINAL['seconds'] = DF_FINAL['HH:MM:SS'].apply(time_to_sec)

# %%
# Removing duplicates
DF_FINAL_NO_DUP = DF_FINAL[['title', 'country', 'time', 'data_from', 'views', 'seconds', 'HH:MM:SS', 'date']]
DF_FINAL_NO_DUP.drop_duplicates(inplace=True)

# %%
df_try = DF_FINAL_NO_DUP.copy()

# %%
df_try_HF = df_try[df_try['data_from'] == 'HF']
df_try_T = df_try[df_try['data_from'] == 'T']

# %%
df_try.head(5)
# Out:
#                                                title country  \
# 0                                   Animation • 2014      US
# 1           Hermitcraft 10 - SPOOKY PUMPKINS! Ep. 26      US
# 4                        How are holograms possible?      US
# 5                            Americans every 4 years      US
# 8  Autumn Jazz Music - Relaxing Piano Jazz Music ...      US
#
#                    time data_from       views  seconds  HH:MM:SS        date
# 0  < 1 hour 45 minutues        HF  4336637.37     6032  01:40:32  October 10
# 1              < 30 min        HF   136732.00     1580  00:26:20  October 10
# 4              < 50 min        HF   694034.00     2784  00:46:24  October 10
# 5               < 1 min        HF      905.00       13  00:00:13  October 10
# 8             > 4 hours        HF   233471.00    42899  11:54:59  October 10

# %% [markdown]
# ## Analysis

# %%
# Ensure views and seconds columns are numeric
df_try['views'] = pd.to_numeric(df_try['views'], errors='coerce')
df_try['seconds'] = pd.to_numeric(df_try['seconds'], errors='coerce')

# Define the new duration bins in seconds
bins = [300, 600,  1200, 1800, 2400, 3000, 3600, 7200, float('inf')]  # 0-1 min, 1-5 min, etc.
labels = [
    '< 5 mins', 
    '< 10 mins', 
    '< 20 mins', 
    '< 30 mins',
    '< 40 mins',
    '< 50 mins',
    '1+ hour',
    '2+ hours'
]

# Create a new column with the binned durations
df_try['duration_category'] = pd.cut(df_try['seconds'], bins=bins, labels=labels)

# %%
# Group by country and duration category
duration_vs_views_by_country = df_try.groupby(['country', 'duration_category']).agg(
    total_views=('views', 'sum'),
    avg_views=('views', 'mean'),
    video_count=('title', 'count'),  # Number of videos per category
    max_views=('views', 'max')
).reset_index()

# Pivot the data for easier plotting
pivot_data = duration_vs_views_by_country.pivot(index='country', columns='duration_category', values='avg_views')

# %%
# Bar plot
pivot_data.plot(kind='bar', stacked=False, figsize=(12, 8))
plt.title('Average views per country and duration category')
plt.ylabel('Average views')
plt.xlabel('Country')
plt.legend(title='Duration Category')
plt.show()

# %%
# Group by country and date
duration_vs_views_by_country = df_try.groupby(['country', 'date']).agg(
    total_views=('views', 'sum'),
    avg_views=('views', 'mean'),
    video_count=('title', 'count'),  # Number of videos per category
    max_views=('views', 'max')
).reset_index()

# Pivot the data for easier plotting
pivot_data = duration_vs_views_by_country.pivot(index='date', columns='country', values='video_count')

# Bar plot 
pivot_data.plot.line(x=None, y=None, figsize=(12, 8))
plt.title('Total Views by Country and Video Duration Category')
plt.ylabel('Total Views')
plt.xlabel('Date')
plt.legend(title='Country')
plt.show()

# %%
# Group by country and date
duration_vs_views_by_country = df_try.groupby(['country', 'data_from']).agg(
    total_views=('views', 'sum'),
    avg_views=('views', 'mean'),
    video_count=('title', 'count'),  # Number of videos per category
    max_views=('views', 'max'),
    min_views=('views', 'min')
).reset_index()

pivot_data = duration_vs_views_by_country.pivot(index='country', columns='data_from', values='max_views')

pivot_data.plot(kind='bar', stacked=False, figsize=(12, 8))
plt.title('')
plt.ylabel('Max Views')
plt.xlabel('Country')
plt.legend(title='')
plt.show()

# %%
## Per country

# %%
df_time = df_try[(df_try['country']== 'CA') &(df_try['views']) & (df_try['seconds']) & (df_try['time'])]

# %%
# Group by country and duration category
duration_vs_views_by_country = df_time.groupby(['data_from', 'duration_category']).agg(
    total_views=('views', 'sum'),
    avg_views=('views', 'mean'),
    video_count=('title', 'count'),  # Number of videos per category
    max_views=('views', 'max')
).reset_index()

# Pivot the data for easier plotting
pivot_data = duration_vs_views_by_country.pivot(index='data_from', columns='duration_category', values='avg_views')

# Bar plot for total views by duration category in each country
pivot_data.plot(kind='bar', stacked=False, figsize=(12, 8))
plt.title('Average Views per Video Duration - CA')
plt.ylabel('Average Views')
plt.xlabel('Country')
plt.legend(title='Duration Category')
plt.show()

# %%
# Average views per country
avg_views_by_country = df_try.groupby('country')['views'].mean().sort_values(ascending=False)

# Bar plot of average views per country
avg_views_by_country.plot.bar(y='bar', figsize=(12, 6), color='green')
plt.title('Average Views per Country')
plt.ylabel('Average Views')
plt.xlabel('Country')
plt.show()

# %% [markdown]
# ### top videos categories

# %%
df_top_views = df_try[['country', 'title', 'views', 'HH:MM:SS', 'seconds']]
df_top_views.drop_duplicates(subset=['title'],inplace=True)

# %%
# IT

# %%
df_mean_IT
# Out:
#                     mean
# title
# Meditation  4.200427e+06
# Music       3.369433e+07
# Other       3.925533e+07
# Shorts      1.608933e+07
# TV          6.658105e+06
# Youtubers   6.809246e+06

# %%
##Categories in 20 top videos IT
df_most_view_title = df_top_views[(df_top_views['country']== 'IT') &(df_top_views['views'])& (df_top_views['HH:MM:SS'])]
df_IT = df_most_view_title.nlargest(20, 'views')[['title', 'views', 'HH:MM:SS', 'seconds']]


#lowercase the titles
df_IT['title'] = df_IT['title'].str.lower()

df_IT.loc[df_IT['title'].str.contains('jerry', case=False, na=False), 'title'] = 'Cartooons'
df_IT.loc[df_IT['title'].str.contains('mrbeast|shorts|boba|foil|emojis|screws|huh|boat|hack', case=False, na=False), 'title'] = 'Shorts'
df_IT.loc[df_IT['title'].str.contains('mix|audio|rhythm', case=False, na=False), 'title'] = 'Music'
df_IT.loc[df_IT['title'].str.contains('melatonin', case=False, na=False), 'title'] = 'Meditation'
df_IT.loc[df_IT['title'].str.contains('kylian|influencer', case=False, na=False), 'title'] = 'Youtubers'
df_IT.loc[df_IT['title'].str.contains('bölüm', case=False, na=False), 'title'] = 'TV'


categories = ['Cartoons', 'Shorts', 'Music', 'Meditation', 'Youtubers', 'TV']
df_IT['title'] = df_IT['title'].apply(lambda x : x if x in categories else 'Other')

#calculate mean
df_mean_IT=df_IT.groupby('title')['views'].agg(['mean'])

# Bar plot of average views per country
df_mean_IT.plot(kind='bar', figsize=(12, 6), color='blue')
plt.title('Average Views per Cateogry - Top 20 videos (IT)')
plt.ylabel('Average Views')
plt.xlabel('Category')
plt.show()

# %%
## ES

# %%
##Categories in 20 top videos ES
df_most_view_title = df_top_views[(df_top_views['country']== 'ES') &(df_top_views['views'])& (df_top_views['HH:MM:SS'])]
df_ES = df_most_view_title.nlargest(20, 'views')[['title', 'views', 'HH:MM:SS', 'seconds']]


#lowercase the titles
df_ES['title'] = df_ES['title'].str.lower()

df_ES.loc[df_ES['title'].str.contains('season', case=False, na=False), 'title'] = 'Series'
df_ES.loc[df_ES['title'].str.contains('robot|unauthentic|reflex', case=False, na=False), 'title'] = 'Shorts'
df_ES.loc[df_ES['title'].str.contains('muaiqly|music|playlist|lyrics|shakira|songs|rashed|hip', case=False, na=False), 'title'] = 'Music'
df_ES.loc[df_ES['title'].str.contains('twins|pierdo|jackson|youtuber', case=False, na=False), 'title'] = 'Youtubers'


categories = ['Series', 'Shorts', 'Music', 'Youtubers', 'Other']
df_ES['title'] = df_ES['title'].apply(lambda x : x if x in categories else 'Other')

#calculate mean
df_mean_ES=df_ES.groupby('title')['views'].agg(['mean'])

# Bar plot of average views per country
df_mean_ES.plot(kind='bar', figsize=(12, 6), color='blue')
plt.title('Average Views per Cateogry - Top 20 videos (ES)')
plt.ylabel('Average Views')
plt.xlabel('Category')
plt.show()

# %%
## FR

# %%
##Categories in 20 top videos FR
df_most_view_title = df_top_views[(df_top_views['country']== 'FR') &(df_top_views['views'])& (df_top_views['HH:MM:SS'])]
df_FR = df_most_view_title.nlargest(20, 'views')[['title', 'views', 'HH:MM:SS', 'seconds']]


#lowercase the titles
df_FR['title'] = df_FR['title'].str.lower()

df_FR.loc[df_FR['title'].str.contains('tnews', case=False, na=False), 'title'] = 'News'
df_FR.loc[df_FR['title'].str.contains('musique|music|playlist|rock|quran', case=False, na=False), 'title'] = 'Movies/Trailers'
df_FR.loc[df_FR['title'].str.contains('cartoons', case=False, na=False), 'title'] = 'Cartoons'
df_FR.loc[df_FR['title'].str.contains('rehearsal|sounds', case=False, na=False), 'title'] = 'Music'
df_FR.loc[df_FR['title'].str.contains('youtubeurs|most|meilleur|squeezie|child|hilarant|anecdotes', case=False, na=False), 'title'] = 'Youtubers'
df_FR.loc[df_FR['title'].str.contains('documentary', case=False, na=False), 'title'] = 'Documentary'
df_FR.loc[df_FR['title'].str.contains('housing|comedy', case=False, na=False), 'title'] = 'Other'


categories = ['News', 'Movies/Trailers', 'Cartoons', 'Music', 'Youtubers', 'Documentary', 'Other']
df_FR['title'] = df_FR['title'].apply(lambda x : x if x in categories else 'Other')

#calculate mean
df_mean_FR=df_FR.groupby('title')['views'].agg(['mean'])

# Bar plot of average views per country
df_mean_FR.plot(kind='bar', figsize=(12, 6), color='blue')
plt.title('Average Views per Cateogry - Top 20 videos (FR)')
plt.ylabel('Average Views')
plt.xlabel('Category')
plt.show()

# %%
## NO

# %%
##Categories in 20 top videos NO
df_most_view_title = df_top_views[(df_top_views['country']== 'NO') &(df_top_views['views'])& (df_top_views['HH:MM:SS'])]
df_NO = df_most_view_title.nlargest(20, 'views')[['title', 'views', 'HH:MM:SS', 'seconds']]

#lowercase the titles
df_NO['title'] = df_NO['title'].str.lower()

df_NO.loc[df_NO['title'].str.contains('learning', case=False, na=False), 'title'] = 'Learning'
df_NO.loc[df_NO['title'].str.contains('music|alafasy', case=False, na=False), 'title'] = 'Music'
df_NO.loc[df_NO['title'].str.contains('school', case=False, na=False), 'title'] = 'Youtubers'
df_NO.loc[df_NO['title'].str.contains('lunchly|supgraded|kikakim|trap|arm|hack|minecraft|kicks|lighter|experiment|pitch|watermelon|triple', case=False, na=False), 'title'] = 'Shorts'

categories = ['Learning', 'Music', 'Youtubers', 'Shorts']
df_NO['title'] = df_NO['title'].apply(lambda x : x if x in categories else 'Other')

#calculate mean
df_mean_NO=df_NO.groupby('title')['views'].agg(['mean'])

# Bar plot of average views per country
df_mean_NO.plot(kind='bar', figsize=(12, 6), color='blue')
plt.title('Average Views per Cateogry - Top 20 videos (NO)')
plt.ylabel('Average Views')
plt.xlabel('Category')
plt.show()

# %%
## US

# %%
##Categories in 20 top videos US
df_most_view_title = df_top_views[(df_top_views['country']== 'US') &(df_top_views['views'])& (df_top_views['HH:MM:SS'])]
df_US = df_most_view_title.nlargest(20, 'views')[['title', 'views', 'HH:MM:SS', 'seconds']]

#lowercase the titles
df_US['title'] = df_US['title'].str.lower()

df_US.loc[df_US['title'].str.contains('debate|hurricane', case=False, na=False), 'title'] = 'News'
df_US.loc[df_US['title'].str.contains('movie|opening|dhar|teaser', case=False, na=False), 'title'] = 'Movies/Trailers'
df_US.loc[df_US['title'].str.contains('playlist|music', case=False, na=False), 'title'] = 'Music'
df_US.loc[df_US['title'].str.contains('underground', case=False, na=False), 'title'] = 'VideoGames'
df_US.loc[df_US['title'].str.contains('shift|headquarters|sidemen|alaskan|drive', case=False, na=False), 'title'] = 'Youtubers'
df_US.loc[df_US['title'].str.contains('sketches|nightmares', case=False, na=False), 'title'] = 'TrashTV'
df_US.loc[df_US['title'].str.contains('sea|experiment|gumball', case=False, na=False), 'title'] = 'Other'


categories = ['News', 'Movies/Trailers', 'Music', 'VideoGames', 'Youtubers', 'TrashTV', 'Other']
df_US['title'] = df_US['title'].apply(lambda x : x if x in categories else 'Other')

#calculate mean
df_mean_US=df_US.groupby('title')['views'].agg(['mean'])

# Bar plot of average views per country
df_mean_US.plot(kind='bar', figsize=(12, 6), color='blue')
plt.title('Average Views per Cateogry - Top 20 videos (US)')
plt.ylabel('Average Views')
plt.xlabel('Category')
plt.show()

# %%
## Canada

# %%
##Categories in 20 top videos CA
df_most_view_title = df_top_views[(df_top_views['country']== 'CA') &(df_top_views['views'])& (df_top_views['HH:MM:SS'])]
df_CA = df_most_view_title.nlargest(20, 'views')[['title', 'views', 'HH:MM:SS', 'seconds']]

#lowercase the titles CA
df_CA['title'] = df_CA['title'].str.lower()

df_CA.loc[df_CA['title'].str.contains('flipbook', case=False, na=False), 'title'] = 'Animation'
df_CA.loc[df_CA['title'].str.contains('trailer|teaser', case=False, na=False), 'title'] = 'Movies/Trailers'
df_CA.loc[df_CA['title'].str.contains('music|dj|songs|playlist|mix', case=False, na=False), 'title'] = 'Music'
df_CA.loc[df_CA['title'].str.contains('forced', case=False, na=False), 'title'] = 'Youtubers'
df_CA.loc[df_CA['title'].str.contains('nfl|footballer|football', case=False, na=False), 'title'] = 'Sports'
df_CA.loc[df_CA['title'].str.contains('hiding|internet|tesla|lies', case=False, na=False), 'title'] = 'Other'


categories = ['Animation', 'Movies/Trailers', 'Music', 'Youtubers', 'Sports', 'Other']
df_CA['title'] = df_CA['title'].apply(lambda x : x if x in categories else 'Other')

#calculate mean
df_mean_CA=df_CA.groupby('title')['views'].agg(['mean'])

# Bar plot of average views per country
df_mean_CA.plot(kind='bar', figsize=(12, 6), color='blue')
plt.title('Average Views per Cateogry - Top 20 videos (CA)')
plt.ylabel('Average Views')
plt.xlabel('Category')
plt.show()

# %% [markdown]
# ### correlation

# %%
corr_dic = {
    'IT': '-0.056',
    'ES': '-0.041',
    'FR': '0.005',
    'NO': '-0.080',
    'US': '-0.035'
}
df_corr = pd.Series(corr_dic).astype(float)

# %%
df = pd.DataFrame(df_corr)
df.plot.bar()
# Out:
# <Axes: >

# %%
df_correlation = df_try[(df_try['country'] == 'US') & (df_try['views']) & (df_try['seconds'])]

df_correlation['views'] = pd.to_numeric(df_correlation['views'], errors='coerce')
df_correlation['seconds'] = pd.to_numeric(df_correlation['seconds'], errors='coerce')

df_clean = (df_correlation[['views', 'seconds']].dropna())


correlation, p_value = pearsonr(df_clean['views'], df_clean['seconds'])

# %%
correlation = df_correlation['views'].corr(df_correlation['seconds'])
print(f"Correlation between Video Duration and Views: {correlation}")
# Out:
# Correlation between Video Duration and Views: -0.04144970600086657

# %%
# Visualize the relationship with a scatter plot
plt.figure(figsize=(10,6))
sns.scatterplot(x='seconds', y='views', data=df_clean)
plt.title('Correlation between views and time - US')
plt.xlabel('Duration (Seconds)')
plt.ylabel('Views')
plt.show()

# %%
# Calculate the correlation matrix
corr = df_clean[['seconds', 'views']].corr()

# Create a heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap - Views and Time')
plt.show()

# %%
# Hexbin plot for density visualization
plt.figure(figsize=(12, 6))
plt.hexbin(df_clean['seconds'], df_clean['views'], gridsize=50, cmap='Blues', mincnt=1)

# Add color bar
plt.colorbar(label='Density')

# Add title and axis labels
plt.title('Hexbin Plot of Duration (Seconds) vs Views')
plt.xlabel('Duration (Seconds)')
plt.ylabel('Views')

plt.show()

# %% [markdown]
# ### country, data_from, views

# %%
time_views.plot(kind='bar', figsize=(10,5), title='Average time spent by Country')
plt.ylabel('Average time')
plt.xlabel('Country')
plt.show()

# %%
time_by_country = df_try.groupby('country')['seconds'].mean().sort_values(ascending=False)
time_by_country.plot(kind='bar', figsize=(10,5), title='Average time spent during a week by Country')
plt.ylabel('time - seconds')
plt.xlabel('Country')
plt.show()

# %%
correlation = df2['views'].corr(df2['seconds'])
print(f"Correlation between Video Duration and Views: {correlation}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 correlation = df2['views'].corr(df2['seconds'])
#       2 print(f"Correlation between Video Duration and Views: {correlation}")
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ### trying

# %%
# Bar plot of average views per country
avg_views_by_country.plot(kind='bar', figsize=(12, 6), color='green')
plt.title('Average Views per Country')
plt.ylabel('Average Views')
plt.xlabel('Country')
plt.show()

# %%
# Average views per country
avg_views_by_country = df2.groupby('country')['views'].mean().sort_values(ascending=False)

# Bar plot of average views per country
avg_views_by_country.plot(y='bar', figsize=(12, 6), color='green')
plt.title('Average Views per Country')
plt.ylabel('Average Views')
plt.xlabel('Country')
plt.show()
